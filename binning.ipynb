# %%
# %config IPCompleter.greedy=False
# %config Completer.use_jedi = False

# %%
# !find bwa-mem2
# Out:
# find: ‘bwa-mem2’: No such file or directory

# %%
# !find  /home/gladkov2/anaconda3/ -name "metabat"
# Out:
# /home/gladkov2/anaconda3/bin/metabat
# /home/gladkov2/anaconda3/pkgs/metabat2-2.15-h137b6e9_0/bin/metabat
# /home/gladkov2/anaconda3/envs/metabat
# /home/gladkov2/anaconda3/envs/metabat/bin/metabat

# %%
# !find  /home/gladkov2/storage/ -name "checkm"
# Out:
# /home/gladkov2/storage/temp/serg/checkm

# %% [markdown]
# ### vamb env

# %%
# %cd ~/storage/metagenome/bact_4x/
# %mkdir binning
# %cd binning
# %ll -hS
# Out:
# /mnt/storage/metagenome/bact_4x
# /mnt/storage/metagenome/bact_4x/binning
# total 26G
# -rw-rw-r-- 1 gladkov2 3.8G Oct  8 13:01 26_bwa.sam
# -rw-rw-r-- 1 gladkov2 3.7G Oct  8 13:09 46_bwa.sam
# -rw-rw-r-- 1 gladkov2 3.0G Oct  8 13:00 26_ont.fasta
# -rw-rw-r-- 1 gladkov2 2.9G Oct  8 13:09 46_ont.fasta
# -rw-rw-r-- 1 gladkov2 2.6G Oct  8 12:57 14_bwa.sam
# -rw-rw-r-- 1 gladkov2 2.2G Oct  8 13:06 29_bwa.sam
# -rw-rw-r-- 1 gladkov2 2.1G Oct  8 12:56 14_ont.fasta
# -rw-rw-r-- 1 gladkov2 1.8G Oct  8 13:06 29_ont.fasta
# -rw-rw-r-- 1 gladkov2 1.3G Oct  8 13:06 26_bwa_sorted.bam
# -rw-rw-r-- 1 gladkov2 1.3G Oct  8 13:14 46_bwa_sorted.bam
# -rw-rw-r-- 1 gladkov2 842M Oct  8 13:00 14_bwa_sorted.bam
# -rw-rw-r-- 1 gladkov2 712M Oct  8 13:09 29_bwa_sorted.bam
# -rw-rw-r-- 1 gladkov2 109M Oct  8 12:55 46.fq
# -rw-rw-r-- 1 gladkov2  95M Oct  8 12:55 26.fq
# -rw-rw-r-- 1 gladkov2  89M Oct  8 12:55 14.fq
# -rw-rw-r-- 1 gladkov2  88M Oct  8 12:55 29.fq

# %%
d = {"14":["14.fq",
                    "/home/gladkov2/storage/Bact_comm_4x/20200225_1435_MN24173_FAK85519_967910e6_3_6_1_barcoded/barcode01/all.fq",
                    "/home/gladkov2/storage/metagenome/bact_4x/new_con/14_F_wa.fq",
                    "/home/gladkov2/storage/metagenome/bact_4x/new_con/14_R_wa.fq"],
     "26":["26.fq",
                    "/home/gladkov2/storage/Bact_comm_4x/20200225_1435_MN24173_FAK85519_967910e6_3_6_1_barcoded/barcode02/all.fq",
                    "/home/gladkov2/storage/metagenome/bact_4x/new_con/26_F_wa.fq",
                    "/home/gladkov2/storage/metagenome/bact_4x/new_con/26_R_wa.fq"],
     "29":["29.fq",
                    "/home/gladkov2/storage/Bact_comm_4x/20200225_1435_MN24173_FAK85519_967910e6_3_6_1_barcoded/barcode03/all.fq",
                    "/home/gladkov2/storage/metagenome/bact_4x/new_con/29_F_wa.fq",
                    "/home/gladkov2/storage/metagenome/bact_4x/new_con/29_R_wa.fq"],
     "46":["46.fq",
                    "/home/gladkov2/storage/Bact_comm_4x/20200225_1435_MN24173_FAK85519_967910e6_3_6_1_barcoded/barcode04/all.fq",
                    "/home/gladkov2/storage/metagenome/bact_4x/new_con/46_F_wa.fq",
                    "/home/gladkov2/storage/metagenome/bact_4x/new_con/46_R_wa.fq"],
    }

d
# Out:
# {'14': ['14.fq',
#   '/home/gladkov2/storage/Bact_comm_4x/20200225_1435_MN24173_FAK85519_967910e6_3_6_1_barcoded/barcode01/all.fq',
#   '/home/gladkov2/storage/metagenome/bact_4x/new_con/14_F_wa.fq',
#   '/home/gladkov2/storage/metagenome/bact_4x/new_con/14_R_wa.fq'],
#  '26': ['26.fq',
#   '/home/gladkov2/storage/Bact_comm_4x/20200225_1435_MN24173_FAK85519_967910e6_3_6_1_barcoded/barcode02/all.fq',
#   '/home/gladkov2/storage/metagenome/bact_4x/new_con/26_F_wa.fq',
#   '/home/gladkov2/storage/metagenome/bact_4x/new_con/26_R_wa.fq'],
#  '29': ['29.fq',
#   '/home/gladkov2/storage/Bact_comm_4x/20200225_1435_MN24173_FAK85519_967910e6_3_6_1_barcoded/barcode03/all.fq',
#   '/home/gladkov2/storage/metagenome/bact_4x/new_con/29_F_wa.fq',
#   '/home/gladkov2/storage/metagenome/bact_4x/new_con/29_R_wa.fq'],
#  '46': ['46.fq',
#   '/home/gladkov2/storage/Bact_comm_4x/20200225_1435_MN24173_FAK85519_967910e6_3_6_1_barcoded/barcode04/all.fq',
#   '/home/gladkov2/storage/metagenome/bact_4x/new_con/46_F_wa.fq',
#   '/home/gladkov2/storage/metagenome/bact_4x/new_con/46_R_wa.fq']}

# %%
# !$ont
# Out:
# /bin/bash: /home/gladkov2/storage/Bact_comm_4x/20200225_1435_MN24173_FAK85519_967910e6_3_6_1_barcoded/barcode01/all.fq: Permission denied

# %%
# !ont = d['14'][1]
# !head $ont
# !sed -n '1~4s/^@/>/p;2~4p' $ont | head

# %%
# Out:
# merge not a valid action
#
#     available actions:
#         `extract`: extract sequences from a fasta file
#         `info`: show info about the fasta file and exit.
#         `split`: split a large fasta file into separate files
#                  and/or into K-mers.
#         `flatten`: flatten a fasta file inplace so that later
#                    command-line (and programmattic) access via
#                    pyfasta will use the inplace flattened version
#                    rather than creating another .flat copy of the
#                    sequence.
#
#     to view the help for a particular action, use:
#         pyfasta [action] --help
#     e.g.:
#         pyfasta extract --help

# %%
# %rm *
# !cp /home/gladkov2/storage/metagenome/bact_4x/new_con/diamond/con/14.faa 14.fq
# !cp /home/gladkov2/storage/metagenome/bact_4x/new_con/diamond/con/26.faa 26.fq
# !cp /home/gladkov2/storage/metagenome/bact_4x/new_con/diamond/con/29.faa 29.fq
# !cp /home/gladkov2/storage/metagenome/bact_4x/new_con/diamond/con/46.faa 46.fq
# !sed -n '1~4s/^@/>/p;2~4p' $ont | head

# %%
ont = d[f][1]
# !head $ont
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-5fe1ba162f8e> in <module>
# ----> 1 ont = d[f][1]
#       2 get_ipython().system('head $ont')
#
# NameError: name 'd' is not defined

# %%
# !bwa-mem2 mem -t 50 14.fq 14_ont.fasta > test.sam

# %%
# !samtools sort test.sam > test.bam
# Out:
# [bam_sort_core] merging from 5 files and 1 in-memory blocks...

# %%
for f in d:
    con = d[f][0]
    mi_f = d[f][2]
    mi_r = d[f][3]
    ont = d[f][1]
    # !sed -n '1~4s/^@/>/p;2~4p' $ont > $f\_ont.fasta
    # !minimap2 -ax map-ont $con  $f\_ont.fasta $mi_f $mi_r -t 50  > $f\_bwa.sam
    # !samtools sort $f\_bwa.sam > $f\_bwa_sorted.bam
# Out:
# [M::mm_idx_gen::2.191*1.30] collected minimizers
# [M::mm_idx_gen::4.686*2.25] sorted minimizers
# [M::main::4.687*2.25] loaded/built the index for 1903 target sequence(s)
# [M::mm_mapopt_update::4.904*2.20] mid_occ = 32
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 1903
# [M::mm_idx_stat::5.012*2.17] distinct minimizers: 11752665 (78.56% are singletons); average occurrences: 1.458; average spacing: 5.359
# [M::worker_pipeline::13.696*27.45] mapped 165675 sequences
# [M::worker_pipeline::18.378*33.18] mapped 167791 sequences
# [M::worker_pipeline::21.642*34.93] mapped 168228 sequences
# [M::worker_pipeline::25.580*33.65] mapped 167010 sequences
# [M::worker_pipeline::25.887*33.27] mapped 18490 sequences
# [M::worker_pipeline::26.324*32.93] mapped 170049 sequences
# [M::worker_pipeline::26.784*32.60] mapped 170049 sequences
# [M::main] Version: 2.17-r941
# [M::main] CMD: minimap2 -ax map-ont -t 50 14.fq 14_ont.fasta /home/gladkov2/storage/metagenome/bact_4x/new_con/14_F_wa.fq /home/gladkov2/storage/metagenome/bact_4x/new_con/14_R_wa.fq
# [M::main] Real time: 26.891 sec; CPU: 873.219 sec; Peak RSS: 4.738 GB
# [bam_sort_core] merging from 4 files and 1 in-memory blocks...
# [M::mm_idx_gen::2.414*1.29] collected minimizers
# [M::mm_idx_gen::3.128*2.84] sorted minimizers
# [M::main::3.128*2.84] loaded/built the index for 1589 target sequence(s)
# [M::mm_mapopt_update::3.356*2.72] mid_occ = 32
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 1589
# [M::mm_idx_stat::3.477*2.66] distinct minimizers: 12434700 (78.28% are singletons); average occurrences: 1.464; average spacing: 5.358
# [M::worker_pipeline::13.829*32.26] mapped 166217 sequences
# [M::worker_pipeline::17.164*33.63] mapped 165938 sequences
# [M::worker_pipeline::21.409*36.89] mapped 168032 sequences
# [M::worker_pipeline::25.183*38.69] mapped 168103 sequences
# [M::worker_pipeline::29.703*40.31] mapped 168850 sequences
# [M::worker_pipeline::32.491*37.89] mapped 170567 sequences
# [M::worker_pipeline::32.674*37.69] mapped 5047 sequences
# [M::worker_pipeline::33.075*37.40] mapped 144038 sequences
# [M::worker_pipeline::33.553*37.06] mapped 144038 sequences
# [M::main] Version: 2.17-r941
# [M::main] CMD: minimap2 -ax map-ont -t 50 26.fq 26_ont.fasta /home/gladkov2/storage/metagenome/bact_4x/new_con/26_F_wa.fq /home/gladkov2/storage/metagenome/bact_4x/new_con/26_R_wa.fq
# [M::main] Real time: 33.668 sec; CPU: 1243.424 sec; Peak RSS: 4.539 GB
# [bam_sort_core] merging from 7 files and 1 in-memory blocks...
# [M::mm_idx_gen::2.145*1.31] collected minimizers
# [M::mm_idx_gen::2.781*2.91] sorted minimizers
# [M::main::2.782*2.91] loaded/built the index for 1519 target sequence(s)
# [M::mm_mapopt_update::3.018*2.76] mid_occ = 25
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 1519
# [M::mm_idx_stat::3.156*2.68] distinct minimizers: 12578691 (81.83% are singletons); average occurrences: 1.352; average spacing: 5.357
# [M::worker_pipeline::11.500*31.29] mapped 174887 sequences
# [M::worker_pipeline::16.058*36.55] mapped 177473 sequences
# [M::worker_pipeline::18.880*36.80] mapped 175827 sequences
# [M::worker_pipeline::19.886*34.99] mapped 79661 sequences
# [M::worker_pipeline::20.407*34.36] mapped 150978 sequences
# [M::worker_pipeline::20.884*33.85] mapped 150978 sequences
# [M::main] Version: 2.17-r941
# [M::main] CMD: minimap2 -ax map-ont -t 50 29.fq 29_ont.fasta /home/gladkov2/storage/metagenome/bact_4x/new_con/29_F_wa.fq /home/gladkov2/storage/metagenome/bact_4x/new_con/29_R_wa.fq
# [M::main] Real time: 20.981 sec; CPU: 707.131 sec; Peak RSS: 4.574 GB
# [bam_sort_core] merging from 4 files and 1 in-memory blocks...
# [M::mm_idx_gen::2.595*1.38] collected minimizers
# [M::mm_idx_gen::3.369*3.17] sorted minimizers
# [M::main::3.369*3.17] loaded/built the index for 1682 target sequence(s)
# [M::mm_mapopt_update::3.692*2.98] mid_occ = 30
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 1682
# [M::mm_idx_stat::3.891*2.88] distinct minimizers: 14347284 (78.10% are singletons); average occurrences: 1.458; average spacing: 5.359
# [M::worker_pipeline::12.932*29.76] mapped 161990 sequences
# [M::worker_pipeline::17.104*34.42] mapped 161556 sequences
# [M::worker_pipeline::20.421*35.94] mapped 160818 sequences
# [M::worker_pipeline::24.741*38.41] mapped 161469 sequences
# [M::worker_pipeline::28.280*39.87] mapped 163187 sequences
# [M::worker_pipeline::30.945*37.78] mapped 141280 sequences
# [M::worker_pipeline::31.843*37.07] mapped 325975 sequences
# [M::worker_pipeline::32.761*36.38] mapped 325975 sequences
# [M::main] Version: 2.17-r941
# [M::main] CMD: minimap2 -ax map-ont -t 50 46.fq 46_ont.fasta /home/gladkov2/storage/metagenome/bact_4x/new_con/46_F_wa.fq /home/gladkov2/storage/metagenome/bact_4x/new_con/46_R_wa.fq
# [M::main] Real time: 32.871 sec; CPU: 1192.083 sec; Peak RSS: 4.743 GB
# [bam_sort_core] merging from 7 files and 1 in-memory blocks...

# %%
# %%bash
#
# minimap2 -ax map-ont 14.fq  14_ont.fasta /home/gladkov2/storage/metagenome/bact_4x/new_con/14_F_wa.fq  /home/gladkov2/storage/metagenome/bact_4x/new_con/14_R_wa.fq -t 50 > test5.sam
# samtools sort test5.sam > test5.bam
# samtools flagstat test5.bam
# Out:
# 1084633 + 0 in total (QC-passed reads + QC-failed reads)
# 29790 + 0 secondary
# 27551 + 0 supplementary
# 0 + 0 duplicates
# 802588 + 0 mapped (74.00% : N/A)
# 0 + 0 paired in sequencing
# 0 + 0 read1
# 0 + 0 read2
# 0 + 0 properly paired (N/A : N/A)
# 0 + 0 with itself and mate mapped
# 0 + 0 singletons (N/A : N/A)
# 0 + 0 with mate mapped to a different chr
# 0 + 0 with mate mapped to a different chr (mapQ>=5)
# [M::mm_idx_gen::2.160*1.32] collected minimizers
# [M::mm_idx_gen::2.632*2.70] sorted minimizers
# [M::main::2.633*2.70] loaded/built the index for 1903 target sequence(s)
# [M::mm_mapopt_update::2.837*2.58] mid_occ = 32
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 1903
# [M::mm_idx_stat::2.940*2.53] distinct minimizers: 11752665 (78.56% are singletons); average occurrences: 1.458; average spacing: 5.359
# [M::worker_pipeline::12.510*32.57] mapped 165675 sequences
# [M::worker_pipeline::16.321*36.56] mapped 167791 sequences
# [M::worker_pipeline::20.448*39.13] mapped 168228 sequences
# [M::worker_pipeline::23.738*36.84] mapped 167010 sequences
# [M::worker_pipeline::24.031*36.40] mapped 18490 sequences
# [M::worker_pipeline::24.477*35.97] mapped 170049 sequences
# [M::worker_pipeline::24.939*35.55] mapped 170049 sequences
# [M::main] Version: 2.17-r941
# [M::main] CMD: minimap2 -ax map-ont -t 50 14.fq 14_ont.fasta /home/gladkov2/storage/metagenome/bact_4x/new_con/14_F_wa.fq /home/gladkov2/storage/metagenome/bact_4x/new_con/14_R_wa.fq
# [M::main] Real time: 25.041 sec; CPU: 886.746 sec; Peak RSS: 4.688 GB
# [bam_sort_core] merging from 4 files and 1 in-memory blocks...

# %%
# %%bash
#
# rm test4.sam test4.bam
# bwa-mem2 mem -t 50 14.fq 14_temp_f.fq /home/gladkov2/storage/metagenome/bact_4x/new_con/14_R_wa.fq  > test4.sam
# samtools sort test4.sam > test4.bam
# samtools flagstat test4.bam

# %%
for f in d:
    print(f'\n{f}')
    # !samtools flagstat $f\_bwa_sorted.bam
# Out:
# 14
# 1084633 + 0 in total (QC-passed reads + QC-failed reads)
# 29790 + 0 secondary
# 27551 + 0 supplementary
# 0 + 0 duplicates
# 802588 + 0 mapped (74.00% : N/A)
# 0 + 0 paired in sequencing
# 0 + 0 read1
# 0 + 0 read2
# 0 + 0 properly paired (N/A : N/A)
# 0 + 0 with itself and mate mapped
# 0 + 0 singletons (N/A : N/A)
# 0 + 0 with mate mapped to a different chr
# 0 + 0 with mate mapped to a different chr (mapQ>=5)
#
# 26
# 1360549 + 0 in total (QC-passed reads + QC-failed reads)
# 27936 + 0 secondary
# 31783 + 0 supplementary
# 0 + 0 duplicates
# 1209509 + 0 mapped (88.90% : N/A)
# 0 + 0 paired in sequencing
# 0 + 0 read1
# 0 + 0 read2
# 0 + 0 properly paired (N/A : N/A)
# 0 + 0 with itself and mate mapped
# 0 + 0 singletons (N/A : N/A)
# 0 + 0 with mate mapped to a different chr
# 0 + 0 with mate mapped to a different chr (mapQ>=5)
#
# 29
# 955338 + 0 in total (QC-passed reads + QC-failed reads)
# 25870 + 0 secondary
# 19664 + 0 supplementary
# 0 + 0 duplicates
# 740807 + 0 mapped (77.54% : N/A)
# 0 + 0 paired in sequencing
# 0 + 0 read1
# 0 + 0 read2
# 0 + 0 properly paired (N/A : N/A)
# 0 + 0 with itself and mate mapped
# 0 + 0 singletons (N/A : N/A)
# 0 + 0 with mate mapped to a different chr
# 0 + 0 with mate mapped to a different chr (mapQ>=5)
#
# 46
# 1671656 + 0 in total (QC-passed reads + QC-failed reads)
# 41636 + 0 secondary
# 27770 + 0 supplementary
# 0 + 0 duplicates
# 1400623 + 0 mapped (83.79% : N/A)
# 0 + 0 paired in sequencing
# 0 + 0 read1
# 0 + 0 read2
# 0 + 0 properly paired (N/A : N/A)
# 0 + 0 with itself and mate mapped
# 0 + 0 singletons (N/A : N/A)
# 0 + 0 with mate mapped to a different chr
# 0 + 0 with mate mapped to a different chr (mapQ>=5)

# %% [markdown]
# ### change env to metabat

# %%
# !ls -lh
d
# Out:
# total 26G
# -rw-rw-r-- 1 gladkov2 gladkov2  89M Oct  8 12:55 14.fq
# -rw-rw-r-- 1 gladkov2 gladkov2 2.6G Oct  8 12:57 14_bwa.sam
# -rw-rw-r-- 1 gladkov2 gladkov2 842M Oct  8 13:00 14_bwa_sorted.bam
# -rw-rw-r-- 1 gladkov2 gladkov2 2.1G Oct  8 12:56 14_ont.fasta
# -rw-rw-r-- 1 gladkov2 gladkov2  95M Oct  8 12:55 26.fq
# -rw-rw-r-- 1 gladkov2 gladkov2 3.8G Oct  8 13:01 26_bwa.sam
# -rw-rw-r-- 1 gladkov2 gladkov2 1.3G Oct  8 13:06 26_bwa_sorted.bam
# -rw-rw-r-- 1 gladkov2 gladkov2 3.0G Oct  8 13:00 26_ont.fasta
# -rw-rw-r-- 1 gladkov2 gladkov2  88M Oct  8 12:55 29.fq
# -rw-rw-r-- 1 gladkov2 gladkov2 2.2G Oct  8 13:06 29_bwa.sam
# -rw-rw-r-- 1 gladkov2 gladkov2 712M Oct  8 13:09 29_bwa_sorted.bam
# -rw-rw-r-- 1 gladkov2 gladkov2 1.8G Oct  8 13:06 29_ont.fasta
# -rw-rw-r-- 1 gladkov2 gladkov2 109M Oct  8 12:55 46.fq
# -rw-rw-r-- 1 gladkov2 gladkov2 3.7G Oct  8 13:09 46_bwa.sam
# -rw-rw-r-- 1 gladkov2 gladkov2 1.3G Oct  8 13:14 46_bwa_sorted.bam
# -rw-rw-r-- 1 gladkov2 gladkov2 2.9G Oct  8 13:09 46_ont.fasta
# {'14': ['14.fq',
#   '/home/gladkov2/storage/Bact_comm_4x/20200225_1435_MN24173_FAK85519_967910e6_3_6_1_barcoded/barcode01/all.fq',
#   '/home/gladkov2/storage/metagenome/bact_4x/new_con/14_F_wa.fq',
#   '/home/gladkov2/storage/metagenome/bact_4x/new_con/14_R_wa.fq'],
#  '26': ['26.fq',
#   '/home/gladkov2/storage/Bact_comm_4x/20200225_1435_MN24173_FAK85519_967910e6_3_6_1_barcoded/barcode02/all.fq',
#   '/home/gladkov2/storage/metagenome/bact_4x/new_con/26_F_wa.fq',
#   '/home/gladkov2/storage/metagenome/bact_4x/new_con/26_R_wa.fq'],
#  '29': ['29.fq',
#   '/home/gladkov2/storage/Bact_comm_4x/20200225_1435_MN24173_FAK85519_967910e6_3_6_1_barcoded/barcode03/all.fq',
#   '/home/gladkov2/storage/metagenome/bact_4x/new_con/29_F_wa.fq',
#   '/home/gladkov2/storage/metagenome/bact_4x/new_con/29_R_wa.fq'],
#  '46': ['46.fq',
#   '/home/gladkov2/storage/Bact_comm_4x/20200225_1435_MN24173_FAK85519_967910e6_3_6_1_barcoded/barcode04/all.fq',
#   '/home/gladkov2/storage/metagenome/bact_4x/new_con/46_F_wa.fq',
#   '/home/gladkov2/storage/metagenome/bact_4x/new_con/46_R_wa.fq']}

# %%
for f in d:
    # !jgi_summarize_bam_contig_depths --outputDepth $f\_depth.txt --referenceFasta $f\.fq  $f\_bwa_sorted.bam
# Out:
# Output depth matrix to 14_depth.txt
# Reference fasta file 14.fq
# Output matrix to 14_depth.txt
# Reading reference fasta file: 14.fq
# ... 1903 sequences
# Opening 1 bams
# Consolidating headers
# Processing bam files
# Thread 0 finished: 14_bwa_sorted.bam with 1084633 reads and 169783 readsWellMapped
# Creating depth matrix file: 14_depth.txt
# Closing most bam files
# Closing last bam file
# Finished
# Output depth matrix to 26_depth.txt
# Reference fasta file 26.fq
# Output matrix to 26_depth.txt
# Reading reference fasta file: 26.fq
# ... 1589 sequences
# Opening 1 bams
# Consolidating headers
# Processing bam files
# Thread 0 finished: 26_bwa_sorted.bam with 1360549 reads and 191790 readsWellMapped
# Creating depth matrix file: 26_depth.txt
# Closing most bam files
# Closing last bam file
# Finished
# Output depth matrix to 29_depth.txt
# Reference fasta file 29.fq
# Output matrix to 29_depth.txt
# Reading reference fasta file: 29.fq
# ... 1519 sequences
# Opening 1 bams
# Consolidating headers
# Processing bam files
# Thread 0 finished: 29_bwa_sorted.bam with 955338 reads and 166009 readsWellMapped
# Creating depth matrix file: 29_depth.txt
# Closing most bam files
# Closing last bam file
# Finished
# Output depth matrix to 46_depth.txt
# Reference fasta file 46.fq
# Output matrix to 46_depth.txt
# Reading reference fasta file: 46.fq
# ... 1682 sequences
# Opening 1 bams
# Consolidating headers
# Processing bam files
# Thread 0 finished: 46_bwa_sorted.bam with 1671656 reads and 419608 readsWellMapped
# Creating depth matrix file: 46_depth.txt
# Closing most bam files
# Closing last bam file
# Finished

# %%
for f in d:
    # !metabat2 -i $f\.fq -o mags/$f\_gen_cov -a  $f\_depth.txt
    # !metabat2 -i $f\.fq -o mags/$f\_gen_w_cov
# !checkm lineage_wf -x fa  -f checkm/N2_MAGs_checkm.tab -t 50 mags/ checkm/
# !checkm qa ./checkm/lineage.ms ./checkm -o 2 -f res --tab_table -t 50
# Out:
# MetaBAT 2 (v2.12.1) using minContig 2500, minCV 1.0, minCVSum 1.0, maxP 95%, minS 60, and maxEdges 200.
# 2 bins (4266870 bases in total) formed.
# MetaBAT 2 (v2.12.1) using minContig 2500, minCV 1.0, minCVSum 1.0, maxP 95%, minS 60, and maxEdges 200.
# 22 bins (88398034 bases in total) formed.
# MetaBAT 2 (v2.12.1) using minContig 2500, minCV 1.0, minCVSum 1.0, maxP 95%, minS 60, and maxEdges 200.
# 0 bins (0 bases in total) formed.
# MetaBAT 2 (v2.12.1) using minContig 2500, minCV 1.0, minCVSum 1.0, maxP 95%, minS 60, and maxEdges 200.
# 19 bins (95396352 bases in total) formed.
# MetaBAT 2 (v2.12.1) using minContig 2500, minCV 1.0, minCVSum 1.0, maxP 95%, minS 60, and maxEdges 200.
# 0 bins (0 bases in total) formed.
# MetaBAT 2 (v2.12.1) using minContig 2500, minCV 1.0, minCVSum 1.0, maxP 95%, minS 60, and maxEdges 200.
# 22 bins (88789908 bases in total) formed.
# MetaBAT 2 (v2.12.1) using minContig 2500, minCV 1.0, minCVSum 1.0, maxP 95%, minS 60, and maxEdges 200.
# 3 bins (12204608 bases in total) formed.
# MetaBAT 2 (v2.12.1) using minContig 2500, minCV 1.0, minCVSum 1.0, maxP 95%, minS 60, and maxEdges 200.
# 32 bins (109310530 bases in total) formed.
# [2021-10-08 14:32:18] INFO: CheckM v1.1.3
# [2021-10-08 14:32:18] INFO: checkm lineage_wf -x fa -f checkm/N2_MAGs_checkm.tab -t 50 mags/ checkm/
# [2021-10-08 14:32:18] INFO: [CheckM - tree] Placing bins in reference genome tree.
# [2021-10-08 14:32:21] INFO: Identifying marker genes in 100 bins with 50 threads:
#     Finished processing 100 of 100 (100.00%) bins.
# [2021-10-08 14:34:56] INFO: Saving HMM info to file.
# [2021-10-08 14:34:56] INFO: Calculating genome statistics for 100 bins with 50 threads:
#     Finished processing 100 of 100 (100.00%) bins.
# [2021-10-08 14:34:57] INFO: Extracting marker genes to align.
# [2021-10-08 14:34:57] INFO: Parsing HMM hits to marker genes:
#     Finished parsing hits for 100 of 100 (100.00%) bins.
# [2021-10-08 14:35:02] INFO: Extracting 43 HMMs with 50 threads:
#     Finished extracting 43 of 43 (100.00%) HMMs.
# [2021-10-08 14:35:02] INFO: Aligning 43 marker genes with 50 threads:
#     Finished aligning 43 of 43 (100.00%) marker genes.
# [2021-10-08 14:35:04] INFO: Reading marker alignment files.
# [2021-10-08 14:35:04] INFO: Concatenating alignments.
# [2021-10-08 14:35:04] INFO: Placing 100 bins into the genome tree with pplacer (be patient).
# [2021-10-08 14:45:23] INFO: { Current stage: 0:13:04.949 || Total: 0:13:04.949 }
# [2021-10-08 14:45:23] INFO: [CheckM - lineage_set] Inferring lineage-specific marker sets.
# [2021-10-08 14:45:23] INFO: Reading HMM info from file.
# [2021-10-08 14:45:23] INFO: Parsing HMM hits to marker genes:
#     Finished parsing hits for 100 of 100 (100.00%) bins.
# [2021-10-08 14:45:27] INFO: Determining marker sets for each genome bin.
#     Finished processing 100 of 100 (100.00%) bins (current: 14_gen_cov.1).
# [2021-10-08 14:45:36] INFO: Marker set written to: checkm/lineage.ms
# [2021-10-08 14:45:36] INFO: { Current stage: 0:00:12.574 || Total: 0:13:17.524 }
# [2021-10-08 14:45:36] INFO: [CheckM - analyze] Identifying marker genes in bins.
# [2021-10-08 14:45:38] INFO: Identifying marker genes in 100 bins with 50 threads:
#     Finished processing 100 of 100 (100.00%) bins.
# [2021-10-08 14:51:23] INFO: Saving HMM info to file.
# [2021-10-08 14:51:26] INFO: { Current stage: 0:05:50.556 || Total: 0:19:08.080 }
# [2021-10-08 14:51:26] INFO: Parsing HMM hits to marker genes:
#     Finished parsing hits for 100 of 100 (100.00%) bins.
# [2021-10-08 14:51:58] INFO: Aligning marker genes with multiple hits in a single bin:
#     Finished processing 100 of 100 (100.00%) bins.
# [2021-10-08 14:54:34] INFO: { Current stage: 0:03:07.884 || Total: 0:22:15.964 }
# [2021-10-08 14:54:34] INFO: Calculating genome statistics for 100 bins with 50 threads:
#     Finished processing 100 of 100 (100.00%) bins.
# [2021-10-08 14:54:35] INFO: { Current stage: 0:00:01.030 || Total: 0:22:16.995 }
# [2021-10-08 14:54:35] INFO: [CheckM - qa] Tabulating genome statistics.
# [2021-10-08 14:54:35] INFO: Calculating AAI between multi-copy marker genes.
# [2021-10-08 14:54:36] INFO: Reading HMM info from file.
# [2021-10-08 14:54:38] INFO: Parsing HMM hits to marker genes:
#     Finished parsing hits for 100 of 100 (100.00%) bins.
# [2021-10-08 14:55:10] INFO: QA information written to: checkm/N2_MAGs_checkm.tab
# [2021-10-08 14:55:10] INFO: { Current stage: 0:00:34.806 || Total: 0:22:51.802 }
# [2021-10-08 14:55:11] INFO: CheckM v1.1.3
# [2021-10-08 14:55:11] INFO: checkm qa ./checkm/lineage.ms ./checkm -o 2 -f res --tab_table -t 50
# [2021-10-08 14:55:11] INFO: [CheckM - qa] Tabulating genome statistics.
# [2021-10-08 14:55:11] INFO: Calculating AAI between multi-copy marker genes.
# [2021-10-08 14:55:11] INFO: Reading HMM info from file.
# [2021-10-08 14:55:13] INFO: Parsing HMM hits to marker genes:
#     Finished parsing hits for 100 of 100 (100.00%) bins.
# [2021-10-08 14:55:46] INFO: QA information written to: res
# [2021-10-08 14:55:46] INFO: { Current stage: 0:00:34.753 || Total: 0:00:34.753 }
# /bin/bash: mags/*.fa: ambiguous redirect

# %%
# %%bash
#
# FILES="mags/*"
# for f in $FILES
# do
#     barrnap -o $f\_rrna.fa < $f > $f\_rrna.gff
# done
# Out:
# [barrnap] This is barrnap 0.9
# [barrnap] Written by Torsten Seemann
# [barrnap] Obtained from https://github.com/tseemann/barrnap
# [barrnap] Detected operating system: linux
# [barrnap] Adding /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../binaries/linux to end of PATH
# [barrnap] Checking for dependencies:
# [barrnap] Found nhmmer - /home/gladkov2/anaconda3/envs/metabat/bin/nhmmer
# [barrnap] Found bedtools - /home/gladkov2/anaconda3/envs/metabat/bin/bedtools
# [barrnap] Will use 1 threads
# [barrnap] Setting evalue cutoff to 1e-06
# [barrnap] Will tag genes < 0.8 of expected length.
# [barrnap] Will reject genes < 0.25 of expected length.
# [barrnap] Using database: /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm
# [barrnap] Copying STDIN to a temporary file: /tmp/St9fMgSzcS
# [barrnap] Scanning /tmp/St9fMgSzcS for bac rRNA genes... please wait
# [barrnap] Command: nhmmer --cpu 1 -E 1e-06 --w_length 3878 -o /dev/null --tblout /dev/stdout '/home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm' '/tmp/St9fMgSzcS'
# [barrnap] Found 0 ribosomal RNA features.
# [barrnap] Sorting features and outputting GFF3...
# [barrnap] Writing hit sequences to: mags/14_gen_cov.1.fa_rrna.fa
# [barrnap] Running: bedtools getfasta -s -name+ -fo 'mags/14_gen_cov.1.fa_rrna.fa' -fi '/tmp/St9fMgSzcS' -bed '/tmp/urFodpi61E'
# index file /tmp/St9fMgSzcS.fai not found, generating...
# [barrnap] Done.
# [barrnap] This is barrnap 0.9
# [barrnap] Written by Torsten Seemann
# [barrnap] Obtained from https://github.com/tseemann/barrnap
# [barrnap] Detected operating system: linux
# [barrnap] Adding /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../binaries/linux to end of PATH
# [barrnap] Checking for dependencies:
# [barrnap] Found nhmmer - /home/gladkov2/anaconda3/envs/metabat/bin/nhmmer
# [barrnap] Found bedtools - /home/gladkov2/anaconda3/envs/metabat/bin/bedtools
# [barrnap] Will use 1 threads
# [barrnap] Setting evalue cutoff to 1e-06
# [barrnap] Will tag genes < 0.8 of expected length.
# [barrnap] Will reject genes < 0.25 of expected length.
# [barrnap] Using database: /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm
# [barrnap] Copying STDIN to a temporary file: /tmp/XGFrtgtipT
# [barrnap] Scanning /tmp/XGFrtgtipT for bac rRNA genes... please wait
# [barrnap] Command: nhmmer --cpu 1 -E 1e-06 --w_length 3878 -o /dev/null --tblout /dev/stdout '/home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm' '/tmp/XGFrtgtipT'
# [barrnap] Found: 16S_rRNA c109 L=1541/1585 2329..3869 - 16S ribosomal RNA
# [barrnap] Found: 16S_rRNA c1812 L=1541/1585 25672..27212 - 16S ribosomal RNA
# [barrnap] Found: 16S_rRNA c550 L=1454/1585 32..1485 + 16S ribosomal RNA
# [barrnap] Found: 23S_rRNA c1812 L=2875/3232 22250..25124 - 23S ribosomal RNA
# [barrnap] Found: 23S_rRNA c550 L=2875/3232 2034..4908 + 23S ribosomal RNA
# [barrnap] Found: 23S_rRNA c109 L=1781/3232 1..1781 - 23S ribosomal RNA (partial)
# [barrnap] Found: 5S_rRNA c1812 L=103/119 21997..22099 - 5S ribosomal RNA
# [barrnap] Found: 5S_rRNA c550 L=103/119 5059..5161 + 5S ribosomal RNA
# [barrnap] Found 8 ribosomal RNA features.
# [barrnap] Sorting features and outputting GFF3...
# [barrnap] Writing hit sequences to: mags/14_gen_cov.2.fa_rrna.fa
# [barrnap] Running: bedtools getfasta -s -name+ -fo 'mags/14_gen_cov.2.fa_rrna.fa' -fi '/tmp/XGFrtgtipT' -bed '/tmp/yux0X5lbpL'
# index file /tmp/XGFrtgtipT.fai not found, generating...
# [barrnap] Done.
# [barrnap] This is barrnap 0.9
# [barrnap] Written by Torsten Seemann
# [barrnap] Obtained from https://github.com/tseemann/barrnap
# [barrnap] Detected operating system: linux
# [barrnap] Adding /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../binaries/linux to end of PATH
# [barrnap] Checking for dependencies:
# [barrnap] Found nhmmer - /home/gladkov2/anaconda3/envs/metabat/bin/nhmmer
# [barrnap] Found bedtools - /home/gladkov2/anaconda3/envs/metabat/bin/bedtools
# [barrnap] Will use 1 threads
# [barrnap] Setting evalue cutoff to 1e-06
# [barrnap] Will tag genes < 0.8 of expected length.
# [barrnap] Will reject genes < 0.25 of expected length.
# [barrnap] Using database: /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm
# [barrnap] Copying STDIN to a temporary file: /tmp/I9_aCZGnKc
# [barrnap] Scanning /tmp/I9_aCZGnKc for bac rRNA genes... please wait
# [barrnap] Command: nhmmer --cpu 1 -E 1e-06 --w_length 3878 -o /dev/null --tblout /dev/stdout '/home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm' '/tmp/I9_aCZGnKc'
# [barrnap] Found 0 ribosomal RNA features.
# [barrnap] Sorting features and outputting GFF3...
# [barrnap] Writing hit sequences to: mags/14_gen_w_cov.1.fa_rrna.fa
# [barrnap] Running: bedtools getfasta -s -name+ -fo 'mags/14_gen_w_cov.1.fa_rrna.fa' -fi '/tmp/I9_aCZGnKc' -bed '/tmp/G9SvbS1_Rc'
# index file /tmp/I9_aCZGnKc.fai not found, generating...
# [barrnap] Done.
# [barrnap] This is barrnap 0.9
# [barrnap] Written by Torsten Seemann
# [barrnap] Obtained from https://github.com/tseemann/barrnap
# [barrnap] Detected operating system: linux
# [barrnap] Adding /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../binaries/linux to end of PATH
# [barrnap] Checking for dependencies:
# [barrnap] Found nhmmer - /home/gladkov2/anaconda3/envs/metabat/bin/nhmmer
# [barrnap] Found bedtools - /home/gladkov2/anaconda3/envs/metabat/bin/bedtools
# [barrnap] Will use 1 threads
# [barrnap] Setting evalue cutoff to 1e-06
# [barrnap] Will tag genes < 0.8 of expected length.
# [barrnap] Will reject genes < 0.25 of expected length.
# [barrnap] Using database: /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm
# [barrnap] Copying STDIN to a temporary file: /tmp/gyxBzGLHDu
# [barrnap] Scanning /tmp/gyxBzGLHDu for bac rRNA genes... please wait
# [barrnap] Command: nhmmer --cpu 1 -E 1e-06 --w_length 3878 -o /dev/null --tblout /dev/stdout '/home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm' '/tmp/gyxBzGLHDu'
# [barrnap] Found 0 ribosomal RNA features.
# [barrnap] Sorting features and outputting GFF3...
# [barrnap] Writing hit sequences to: mags/14_gen_w_cov.10.fa_rrna.fa
# [barrnap] Running: bedtools getfasta -s -name+ -fo 'mags/14_gen_w_cov.10.fa_rrna.fa' -fi '/tmp/gyxBzGLHDu' -bed '/tmp/fPYexBX9Sb'
# index file /tmp/gyxBzGLHDu.fai not found, generating...
# [barrnap] Done.
# [barrnap] This is barrnap 0.9
# [barrnap] Written by Torsten Seemann
# [barrnap] Obtained from https://github.com/tseemann/barrnap
# [barrnap] Detected operating system: linux
# [barrnap] Adding /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../binaries/linux to end of PATH
# [barrnap] Checking for dependencies:
# [barrnap] Found nhmmer - /home/gladkov2/anaconda3/envs/metabat/bin/nhmmer
# [barrnap] Found bedtools - /home/gladkov2/anaconda3/envs/metabat/bin/bedtools
# [barrnap] Will use 1 threads
# [barrnap] Setting evalue cutoff to 1e-06
# [barrnap] Will tag genes < 0.8 of expected length.
# [barrnap] Will reject genes < 0.25 of expected length.
# [barrnap] Using database: /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm
# [barrnap] Copying STDIN to a temporary file: /tmp/k6fzDGCkz1
# [barrnap] Scanning /tmp/k6fzDGCkz1 for bac rRNA genes... please wait
# [barrnap] Command: nhmmer --cpu 1 -E 1e-06 --w_length 3878 -o /dev/null --tblout /dev/stdout '/home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm' '/tmp/k6fzDGCkz1'
# [barrnap] Found 0 ribosomal RNA features.
# [barrnap] Sorting features and outputting GFF3...
# [barrnap] Writing hit sequences to: mags/14_gen_w_cov.11.fa_rrna.fa
# [barrnap] Running: bedtools getfasta -s -name+ -fo 'mags/14_gen_w_cov.11.fa_rrna.fa' -fi '/tmp/k6fzDGCkz1' -bed '/tmp/CZ3TyeNsAD'
# index file /tmp/k6fzDGCkz1.fai not found, generating...
# [barrnap] Done.
# [barrnap] This is barrnap 0.9
# [barrnap] Written by Torsten Seemann
# [barrnap] Obtained from https://github.com/tseemann/barrnap
# [barrnap] Detected operating system: linux
# [barrnap] Adding /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../binaries/linux to end of PATH
# [barrnap] Checking for dependencies:
# [barrnap] Found nhmmer - /home/gladkov2/anaconda3/envs/metabat/bin/nhmmer
# [barrnap] Found bedtools - /home/gladkov2/anaconda3/envs/metabat/bin/bedtools
# [barrnap] Will use 1 threads
# [barrnap] Setting evalue cutoff to 1e-06
# [barrnap] Will tag genes < 0.8 of expected length.
# [barrnap] Will reject genes < 0.25 of expected length.
# [barrnap] Using database: /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm
# [barrnap] Copying STDIN to a temporary file: /tmp/SB0b_b6lPR
# [barrnap] Scanning /tmp/SB0b_b6lPR for bac rRNA genes... please wait
# [barrnap] Command: nhmmer --cpu 1 -E 1e-06 --w_length 3878 -o /dev/null --tblout /dev/stdout '/home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm' '/tmp/SB0b_b6lPR'
# [barrnap] Found: 16S_rRNA c38 L=1566/1585 55174..56739 + 16S ribosomal RNA
# [barrnap] Found: 23S_rRNA c38 L=2899/3232 57226..60124 + 23S ribosomal RNA
# [barrnap] Found: 5S_rRNA c38 L=111/119 60227..60337 + 5S ribosomal RNA
# [barrnap] Found 3 ribosomal RNA features.
# [barrnap] Sorting features and outputting GFF3...
# [barrnap] Writing hit sequences to: mags/14_gen_w_cov.12.fa_rrna.fa
# [barrnap] Running: bedtools getfasta -s -name+ -fo 'mags/14_gen_w_cov.12.fa_rrna.fa' -fi '/tmp/SB0b_b6lPR' -bed '/tmp/ep9JI_6vKv'
# index file /tmp/SB0b_b6lPR.fai not found, generating...
# [barrnap] Done.
# [barrnap] This is barrnap 0.9
# [barrnap] Written by Torsten Seemann
# [barrnap] Obtained from https://github.com/tseemann/barrnap
# [barrnap] Detected operating system: linux
# [barrnap] Adding /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../binaries/linux to end of PATH
# [barrnap] Checking for dependencies:
# [barrnap] Found nhmmer - /home/gladkov2/anaconda3/envs/metabat/bin/nhmmer
# [barrnap] Found bedtools - /home/gladkov2/anaconda3/envs/metabat/bin/bedtools
# [barrnap] Will use 1 threads
# [barrnap] Setting evalue cutoff to 1e-06
# [barrnap] Will tag genes < 0.8 of expected length.
# [barrnap] Will reject genes < 0.25 of expected length.
# [barrnap] Using database: /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm
# [barrnap] Copying STDIN to a temporary file: /tmp/4P3HduZwid
# [barrnap] Scanning /tmp/4P3HduZwid for bac rRNA genes... please wait
# [barrnap] Command: nhmmer --cpu 1 -E 1e-06 --w_length 3878 -o /dev/null --tblout /dev/stdout '/home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm' '/tmp/4P3HduZwid'
# [barrnap] Found: 5S_rRNA c857 L=108/119 11..118 + 5S ribosomal RNA
# [barrnap] Found 1 ribosomal RNA features.
# [barrnap] Sorting features and outputting GFF3...
# [barrnap] Writing hit sequences to: mags/14_gen_w_cov.13.fa_rrna.fa
# [barrnap] Running: bedtools getfasta -s -name+ -fo 'mags/14_gen_w_cov.13.fa_rrna.fa' -fi '/tmp/4P3HduZwid' -bed '/tmp/y1HFbeNYit'
# index file /tmp/4P3HduZwid.fai not found, generating...
# [barrnap] Done.
# [barrnap] This is barrnap 0.9
# [barrnap] Written by Torsten Seemann
# [barrnap] Obtained from https://github.com/tseemann/barrnap
# [barrnap] Detected operating system: linux
# [barrnap] Adding /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../binaries/linux to end of PATH
# [barrnap] Checking for dependencies:
# [barrnap] Found nhmmer - /home/gladkov2/anaconda3/envs/metabat/bin/nhmmer
# [barrnap] Found bedtools - /home/gladkov2/anaconda3/envs/metabat/bin/bedtools
# [barrnap] Will use 1 threads
# [barrnap] Setting evalue cutoff to 1e-06
# [barrnap] Will tag genes < 0.8 of expected length.
# [barrnap] Will reject genes < 0.25 of expected length.
# [barrnap] Using database: /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm
# [barrnap] Copying STDIN to a temporary file: /tmp/OpIhHnmCRm
# [barrnap] Scanning /tmp/OpIhHnmCRm for bac rRNA genes... please wait
# [barrnap] Command: nhmmer --cpu 1 -E 1e-06 --w_length 3878 -o /dev/null --tblout /dev/stdout '/home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm' '/tmp/OpIhHnmCRm'
# [barrnap] Found: 16S_rRNA c44 L=1481/1585 763710..765190 + 16S ribosomal RNA
# [barrnap] Found: 16S_rRNA c1263 L=1483/1585 39170..40652 + 16S ribosomal RNA
# [barrnap] Found: 16S_rRNA c1753 L=1482/1585 3146..4627 - 16S ribosomal RNA
# [barrnap] Found: 16S_rRNA c349 L=1486/1585 222214..223699 - 16S ribosomal RNA
# [barrnap] Found: 23S_rRNA c1263 L=2840/3232 41654..44493 + 23S ribosomal RNA
# [barrnap] Found: 23S_rRNA c349 L=3029/3232 218519..221547 - 23S ribosomal RNA
# [barrnap] Found: 23S_rRNA c1753 L=2517/3232 1..2517 - 23S ribosomal RNA (partial)
# [barrnap] Found: 23S_rRNA c1798 L=1999/3232 31524..33522 - 23S ribosomal RNA (partial)
# [barrnap] Found: 23S_rRNA c44 L=1032/3232 766192..767223 + 23S ribosomal RNA (partial)
# [barrnap] Found: 5S_rRNA c349 L=110/119 218238..218347 - 5S ribosomal RNA
# [barrnap] Found: 5S_rRNA c1394 L=110/119 122059..122168 - 5S ribosomal RNA
# [barrnap] Found: 5S_rRNA c1909 L=110/119 350..459 + 5S ribosomal RNA
# [barrnap] Found: 5S_rRNA c1798 L=108/119 31328..31435 - 5S ribosomal RNA
# [barrnap] Found: 5S_rRNA c57 L=80/119 109187..109266 - 5S ribosomal RNA (partial)
# [barrnap] Found 14 ribosomal RNA features.
# [barrnap] Sorting features and outputting GFF3...
# [barrnap] Writing hit sequences to: mags/14_gen_w_cov.14.fa_rrna.fa
# [barrnap] Running: bedtools getfasta -s -name+ -fo 'mags/14_gen_w_cov.14.fa_rrna.fa' -fi '/tmp/OpIhHnmCRm' -bed '/tmp/rscHX1IQ9s'
# index file /tmp/OpIhHnmCRm.fai not found, generating...
# [barrnap] Done.
# [barrnap] This is barrnap 0.9
# [barrnap] Written by Torsten Seemann
# [barrnap] Obtained from https://github.com/tseemann/barrnap
# [barrnap] Detected operating system: linux
# [barrnap] Adding /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../binaries/linux to end of PATH
# [barrnap] Checking for dependencies:
# [barrnap] Found nhmmer - /home/gladkov2/anaconda3/envs/metabat/bin/nhmmer
# [barrnap] Found bedtools - /home/gladkov2/anaconda3/envs/metabat/bin/bedtools
# [barrnap] Will use 1 threads
# [barrnap] Setting evalue cutoff to 1e-06
# [barrnap] Will tag genes < 0.8 of expected length.
# [barrnap] Will reject genes < 0.25 of expected length.
# [barrnap] Using database: /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm
# [barrnap] Copying STDIN to a temporary file: /tmp/qt3krgs7QS
# [barrnap] Scanning /tmp/qt3krgs7QS for bac rRNA genes... please wait
# [barrnap] Command: nhmmer --cpu 1 -E 1e-06 --w_length 3878 -o /dev/null --tblout /dev/stdout '/home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm' '/tmp/qt3krgs7QS'
# [barrnap] Found: 16S_rRNA c1772 L=1481/1585 1147..2627 - 16S ribosomal RNA
# [barrnap] Rejecting short 235 nt predicted 23S_rRNA. Adjust via --reject option.
# [barrnap] Found 1 ribosomal RNA features.
# [barrnap] Sorting features and outputting GFF3...
# [barrnap] Writing hit sequences to: mags/14_gen_w_cov.15.fa_rrna.fa
# [barrnap] Running: bedtools getfasta -s -name+ -fo 'mags/14_gen_w_cov.15.fa_rrna.fa' -fi '/tmp/qt3krgs7QS' -bed '/tmp/piqRophjLY'
# index file /tmp/qt3krgs7QS.fai not found, generating...
# [barrnap] Done.
# [barrnap] This is barrnap 0.9
# [barrnap] Written by Torsten Seemann
# [barrnap] Obtained from https://github.com/tseemann/barrnap
# [barrnap] Detected operating system: linux
# [barrnap] Adding /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../binaries/linux to end of PATH
# [barrnap] Checking for dependencies:
# [barrnap] Found nhmmer - /home/gladkov2/anaconda3/envs/metabat/bin/nhmmer
# [barrnap] Found bedtools - /home/gladkov2/anaconda3/envs/metabat/bin/bedtools
# [barrnap] Will use 1 threads
# [barrnap] Setting evalue cutoff to 1e-06
# [barrnap] Will tag genes < 0.8 of expected length.
# [barrnap] Will reject genes < 0.25 of expected length.
# [barrnap] Using database: /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm
# [barrnap] Copying STDIN to a temporary file: /tmp/ukd9vRynOl
# [barrnap] Scanning /tmp/ukd9vRynOl for bac rRNA genes... please wait
# [barrnap] Command: nhmmer --cpu 1 -E 1e-06 --w_length 3878 -o /dev/null --tblout /dev/stdout '/home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm' '/tmp/ukd9vRynOl'
# [barrnap] Found: 16S_rRNA c1335 L=1532/1585 23622..25153 - 16S ribosomal RNA
# [barrnap] Found: 23S_rRNA c1335 L=2885/3232 20051..22935 - 23S ribosomal RNA
# [barrnap] Found 2 ribosomal RNA features.
# [barrnap] Sorting features and outputting GFF3...
# [barrnap] Writing hit sequences to: mags/14_gen_w_cov.16.fa_rrna.fa
# [barrnap] Running: bedtools getfasta -s -name+ -fo 'mags/14_gen_w_cov.16.fa_rrna.fa' -fi '/tmp/ukd9vRynOl' -bed '/tmp/YESGGviwts'
# index file /tmp/ukd9vRynOl.fai not found, generating...
# [barrnap] Done.
# [barrnap] This is barrnap 0.9
# [barrnap] Written by Torsten Seemann
# [barrnap] Obtained from https://github.com/tseemann/barrnap
# [barrnap] Detected operating system: linux
# [barrnap] Adding /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../binaries/linux to end of PATH
# [barrnap] Checking for dependencies:
# [barrnap] Found nhmmer - /home/gladkov2/anaconda3/envs/metabat/bin/nhmmer
# [barrnap] Found bedtools - /home/gladkov2/anaconda3/envs/metabat/bin/bedtools
# [barrnap] Will use 1 threads
# [barrnap] Setting evalue cutoff to 1e-06
# [barrnap] Will tag genes < 0.8 of expected length.
# [barrnap] Will reject genes < 0.25 of expected length.
# [barrnap] Using database: /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm
# [barrnap] Copying STDIN to a temporary file: /tmp/FxWP7iaaPa
# [barrnap] Scanning /tmp/FxWP7iaaPa for bac rRNA genes... please wait
# [barrnap] Command: nhmmer --cpu 1 -E 1e-06 --w_length 3878 -o /dev/null --tblout /dev/stdout '/home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm' '/tmp/FxWP7iaaPa'
# [barrnap] Found: 16S_rRNA c109 L=1541/1585 2329..3869 - 16S ribosomal RNA
# [barrnap] Found: 16S_rRNA c1812 L=1541/1585 25672..27212 - 16S ribosomal RNA
# [barrnap] Found: 16S_rRNA c550 L=1454/1585 32..1485 + 16S ribosomal RNA
# [barrnap] Found: 23S_rRNA c1812 L=2875/3232 22250..25124 - 23S ribosomal RNA
# [barrnap] Found: 23S_rRNA c550 L=2875/3232 2034..4908 + 23S ribosomal RNA
# [barrnap] Found: 23S_rRNA c109 L=1781/3232 1..1781 - 23S ribosomal RNA (partial)
# [barrnap] Found: 5S_rRNA c1812 L=103/119 21997..22099 - 5S ribosomal RNA
# [barrnap] Found: 5S_rRNA c550 L=103/119 5059..5161 + 5S ribosomal RNA
# [barrnap] Found 8 ribosomal RNA features.
# [barrnap] Sorting features and outputting GFF3...
# [barrnap] Writing hit sequences to: mags/14_gen_w_cov.17.fa_rrna.fa
# [barrnap] Running: bedtools getfasta -s -name+ -fo 'mags/14_gen_w_cov.17.fa_rrna.fa' -fi '/tmp/FxWP7iaaPa' -bed '/tmp/Lv6wUhaiuP'
# index file /tmp/FxWP7iaaPa.fai not found, generating...
# [barrnap] Done.
# [barrnap] This is barrnap 0.9
# [barrnap] Written by Torsten Seemann
# [barrnap] Obtained from https://github.com/tseemann/barrnap
# [barrnap] Detected operating system: linux
# [barrnap] Adding /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../binaries/linux to end of PATH
# [barrnap] Checking for dependencies:
# [barrnap] Found nhmmer - /home/gladkov2/anaconda3/envs/metabat/bin/nhmmer
# [barrnap] Found bedtools - /home/gladkov2/anaconda3/envs/metabat/bin/bedtools
# [barrnap] Will use 1 threads
# [barrnap] Setting evalue cutoff to 1e-06
# [barrnap] Will tag genes < 0.8 of expected length.
# [barrnap] Will reject genes < 0.25 of expected length.
# [barrnap] Using database: /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm
# [barrnap] Copying STDIN to a temporary file: /tmp/gtC_l_wMFJ
# [barrnap] Scanning /tmp/gtC_l_wMFJ for bac rRNA genes... please wait
# [barrnap] Command: nhmmer --cpu 1 -E 1e-06 --w_length 3878 -o /dev/null --tblout /dev/stdout '/home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm' '/tmp/gtC_l_wMFJ'
# [barrnap] Found: 16S_rRNA c24 L=1538/1585 1953..3490 - 16S ribosomal RNA
# [barrnap] Found: 16S_rRNA c88 L=1535/1585 818..2352 - 16S ribosomal RNA
# [barrnap] Found: 16S_rRNA c551 L=1306/1585 1..1306 + 16S ribosomal RNA
# [barrnap] Found: 23S_rRNA c551 L=2928/3232 1926..4853 + 23S ribosomal RNA
# [barrnap] Found: 23S_rRNA c88 L=1266/3232 843728..844993 - 23S ribosomal RNA (partial)
# [barrnap] Found: 23S_rRNA c24 L=1478/3232 5..1482 - 23S ribosomal RNA (partial)
# [barrnap] Rejecting short 336 nt predicted 23S_rRNA. Adjust via --reject option.
# [barrnap] Found: 5S_rRNA c551 L=108/119 4977..5084 + 5S ribosomal RNA
# [barrnap] Found: 5S_rRNA c88 L=108/119 843498..843605 - 5S ribosomal RNA
# [barrnap] Found 8 ribosomal RNA features.
# [barrnap] Sorting features and outputting GFF3...
# [barrnap] Writing hit sequences to: mags/14_gen_w_cov.18.fa_rrna.fa
# [barrnap] Running: bedtools getfasta -s -name+ -fo 'mags/14_gen_w_cov.18.fa_rrna.fa' -fi '/tmp/gtC_l_wMFJ' -bed '/tmp/CUJx9UJDIA'
# index file /tmp/gtC_l_wMFJ.fai not found, generating...
# [barrnap] Done.
# [barrnap] This is barrnap 0.9
# [barrnap] Written by Torsten Seemann
# [barrnap] Obtained from https://github.com/tseemann/barrnap
# [barrnap] Detected operating system: linux
# [barrnap] Adding /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../binaries/linux to end of PATH
# [barrnap] Checking for dependencies:
# [barrnap] Found nhmmer - /home/gladkov2/anaconda3/envs/metabat/bin/nhmmer
# [barrnap] Found bedtools - /home/gladkov2/anaconda3/envs/metabat/bin/bedtools
# [barrnap] Will use 1 threads
# [barrnap] Setting evalue cutoff to 1e-06
# [barrnap] Will tag genes < 0.8 of expected length.
# [barrnap] Will reject genes < 0.25 of expected length.
# [barrnap] Using database: /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm
# [barrnap] Copying STDIN to a temporary file: /tmp/aKDnqTCBcS
# [barrnap] Scanning /tmp/aKDnqTCBcS for bac rRNA genes... please wait
# [barrnap] Command: nhmmer --cpu 1 -E 1e-06 --w_length 3878 -o /dev/null --tblout /dev/stdout '/home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm' '/tmp/aKDnqTCBcS'
# [barrnap] Found: 16S_rRNA c273 L=1541/1585 723391..724931 - 16S ribosomal RNA
# [barrnap] Found: 23S_rRNA c273 L=2863/3232 720050..722912 - 23S ribosomal RNA
# [barrnap] Found: 5S_rRNA c273 L=107/119 719805..719911 - 5S ribosomal RNA
# [barrnap] Found 3 ribosomal RNA features.
# [barrnap] Sorting features and outputting GFF3...
# [barrnap] Writing hit sequences to: mags/14_gen_w_cov.19.fa_rrna.fa
# [barrnap] Running: bedtools getfasta -s -name+ -fo 'mags/14_gen_w_cov.19.fa_rrna.fa' -fi '/tmp/aKDnqTCBcS' -bed '/tmp/SvuynJdKL2'
# index file /tmp/aKDnqTCBcS.fai not found, generating...
# [barrnap] Done.
# [barrnap] This is barrnap 0.9
# [barrnap] Written by Torsten Seemann
# [barrnap] Obtained from https://github.com/tseemann/barrnap
# [barrnap] Detected operating system: linux
# [barrnap] Adding /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../binaries/linux to end of PATH
# [barrnap] Checking for dependencies:
# [barrnap] Found nhmmer - /home/gladkov2/anaconda3/envs/metabat/bin/nhmmer
# [barrnap] Found bedtools - /home/gladkov2/anaconda3/envs/metabat/bin/bedtools
# [barrnap] Will use 1 threads
# [barrnap] Setting evalue cutoff to 1e-06
# [barrnap] Will tag genes < 0.8 of expected length.
# [barrnap] Will reject genes < 0.25 of expected length.
# [barrnap] Using database: /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm
# [barrnap] Copying STDIN to a temporary file: /tmp/KgkDZ3QrlP
# [barrnap] Scanning /tmp/KgkDZ3QrlP for bac rRNA genes... please wait
# [barrnap] Command: nhmmer --cpu 1 -E 1e-06 --w_length 3878 -o /dev/null --tblout /dev/stdout '/home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm' '/tmp/KgkDZ3QrlP'
# [barrnap] Found: 16S_rRNA c3 L=1516/1585 498..2013 + 16S ribosomal RNA
# [barrnap] Found: 16S_rRNA c3 L=1515/1585 3258199..3259713 + 16S ribosomal RNA
# [barrnap] Found: 23S_rRNA c3 L=3103/3232 2457..5559 + 23S ribosomal RNA
# [barrnap] Found: 23S_rRNA c578 L=2502/3232 352388..354889 - 23S ribosomal RNA (partial)
# [barrnap] Found: 23S_rRNA c3 L=2849/3232 3260157..3263005 + 23S ribosomal RNA
# [barrnap] Found: 5S_rRNA c3 L=110/119 5665..5774 + 5S ribosomal RNA
# [barrnap] Found: 5S_rRNA c578 L=110/119 352173..352282 - 5S ribosomal RNA
# [barrnap] Found 7 ribosomal RNA features.
# [barrnap] Sorting features and outputting GFF3...
# [barrnap] Writing hit sequences to: mags/14_gen_w_cov.2.fa_rrna.fa
# [barrnap] Running: bedtools getfasta -s -name+ -fo 'mags/14_gen_w_cov.2.fa_rrna.fa' -fi '/tmp/KgkDZ3QrlP' -bed '/tmp/6hF0yy7dSe'
# index file /tmp/KgkDZ3QrlP.fai not found, generating...
# [barrnap] Done.
# [barrnap] This is barrnap 0.9
# [barrnap] Written by Torsten Seemann
# [barrnap] Obtained from https://github.com/tseemann/barrnap
# [barrnap] Detected operating system: linux
# [barrnap] Adding /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../binaries/linux to end of PATH
# [barrnap] Checking for dependencies:
# [barrnap] Found nhmmer - /home/gladkov2/anaconda3/envs/metabat/bin/nhmmer
# [barrnap] Found bedtools - /home/gladkov2/anaconda3/envs/metabat/bin/bedtools
# [barrnap] Will use 1 threads
# [barrnap] Setting evalue cutoff to 1e-06
# [barrnap] Will tag genes < 0.8 of expected length.
# [barrnap] Will reject genes < 0.25 of expected length.
# [barrnap] Using database: /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm
# [barrnap] Copying STDIN to a temporary file: /tmp/RhL_3Qogbx
# [barrnap] Scanning /tmp/RhL_3Qogbx for bac rRNA genes... please wait
# [barrnap] Command: nhmmer --cpu 1 -E 1e-06 --w_length 3878 -o /dev/null --tblout /dev/stdout '/home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm' '/tmp/RhL_3Qogbx'
# [barrnap] Found: 16S_rRNA c12 L=1457/1585 35785..37241 + 16S ribosomal RNA
# [barrnap] Found: 23S_rRNA c1433 L=1164/3232 2078..3241 + 23S ribosomal RNA (partial)
# [barrnap] Found: 23S_rRNA c12 L=952/3232 37946..38897 + 23S ribosomal RNA (partial)
# [barrnap] Found: 5S_rRNA c1433 L=109/119 3321..3429 + 5S ribosomal RNA
# [barrnap] Found 4 ribosomal RNA features.
# [barrnap] Sorting features and outputting GFF3...
# [barrnap] Writing hit sequences to: mags/14_gen_w_cov.20.fa_rrna.fa
# [barrnap] Running: bedtools getfasta -s -name+ -fo 'mags/14_gen_w_cov.20.fa_rrna.fa' -fi '/tmp/RhL_3Qogbx' -bed '/tmp/AnQXsDRQfy'
# index file /tmp/RhL_3Qogbx.fai not found, generating...
# [barrnap] Done.
# [barrnap] This is barrnap 0.9
# [barrnap] Written by Torsten Seemann
# [barrnap] Obtained from https://github.com/tseemann/barrnap
# [barrnap] Detected operating system: linux
# [barrnap] Adding /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../binaries/linux to end of PATH
# [barrnap] Checking for dependencies:
# [barrnap] Found nhmmer - /home/gladkov2/anaconda3/envs/metabat/bin/nhmmer
# [barrnap] Found bedtools - /home/gladkov2/anaconda3/envs/metabat/bin/bedtools
# [barrnap] Will use 1 threads
# [barrnap] Setting evalue cutoff to 1e-06
# [barrnap] Will tag genes < 0.8 of expected length.
# [barrnap] Will reject genes < 0.25 of expected length.
# [barrnap] Using database: /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm
# [barrnap] Copying STDIN to a temporary file: /tmp/jDTAPwvyYN
# [barrnap] Scanning /tmp/jDTAPwvyYN for bac rRNA genes... please wait
# [barrnap] Command: nhmmer --cpu 1 -E 1e-06 --w_length 3878 -o /dev/null --tblout /dev/stdout '/home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm' '/tmp/jDTAPwvyYN'
# [barrnap] Found 0 ribosomal RNA features.
# [barrnap] Sorting features and outputting GFF3...
# [barrnap] Writing hit sequences to: mags/14_gen_w_cov.21.fa_rrna.fa
# [barrnap] Running: bedtools getfasta -s -name+ -fo 'mags/14_gen_w_cov.21.fa_rrna.fa' -fi '/tmp/jDTAPwvyYN' -bed '/tmp/9nQLrwjqxG'
# index file /tmp/jDTAPwvyYN.fai not found, generating...
# [barrnap] Done.
# [barrnap] This is barrnap 0.9
# [barrnap] Written by Torsten Seemann
# [barrnap] Obtained from https://github.com/tseemann/barrnap
# [barrnap] Detected operating system: linux
# [barrnap] Adding /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../binaries/linux to end of PATH
# [barrnap] Checking for dependencies:
# [barrnap] Found nhmmer - /home/gladkov2/anaconda3/envs/metabat/bin/nhmmer
# [barrnap] Found bedtools - /home/gladkov2/anaconda3/envs/metabat/bin/bedtools
# [barrnap] Will use 1 threads
# [barrnap] Setting evalue cutoff to 1e-06
# [barrnap] Will tag genes < 0.8 of expected length.
# [barrnap] Will reject genes < 0.25 of expected length.
# [barrnap] Using database: /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm
# [barrnap] Copying STDIN to a temporary file: /tmp/q8zRoX5rcr
# [barrnap] Scanning /tmp/q8zRoX5rcr for bac rRNA genes... please wait
# [barrnap] Command: nhmmer --cpu 1 -E 1e-06 --w_length 3878 -o /dev/null --tblout /dev/stdout '/home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm' '/tmp/q8zRoX5rcr'
# [barrnap] Rejecting short 124 nt predicted 23S_rRNA. Adjust via --reject option.
# [barrnap] Found: 5S_rRNA c1233 L=99/119 290..388 + 5S ribosomal RNA
# [barrnap] Found 1 ribosomal RNA features.
# [barrnap] Sorting features and outputting GFF3...
# [barrnap] Writing hit sequences to: mags/14_gen_w_cov.22.fa_rrna.fa
# [barrnap] Running: bedtools getfasta -s -name+ -fo 'mags/14_gen_w_cov.22.fa_rrna.fa' -fi '/tmp/q8zRoX5rcr' -bed '/tmp/zoQ8HQP2mb'
# index file /tmp/q8zRoX5rcr.fai not found, generating...
# [barrnap] Done.
# [barrnap] This is barrnap 0.9
# [barrnap] Written by Torsten Seemann
# [barrnap] Obtained from https://github.com/tseemann/barrnap
# [barrnap] Detected operating system: linux
# [barrnap] Adding /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../binaries/linux to end of PATH
# [barrnap] Checking for dependencies:
# [barrnap] Found nhmmer - /home/gladkov2/anaconda3/envs/metabat/bin/nhmmer
# [barrnap] Found bedtools - /home/gladkov2/anaconda3/envs/metabat/bin/bedtools
# [barrnap] Will use 1 threads
# [barrnap] Setting evalue cutoff to 1e-06
# [barrnap] Will tag genes < 0.8 of expected length.
# [barrnap] Will reject genes < 0.25 of expected length.
# [barrnap] Using database: /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm
# [barrnap] Copying STDIN to a temporary file: /tmp/WAtVQWM_hj
# [barrnap] Scanning /tmp/WAtVQWM_hj for bac rRNA genes... please wait
# [barrnap] Command: nhmmer --cpu 1 -E 1e-06 --w_length 3878 -o /dev/null --tblout /dev/stdout '/home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm' '/tmp/WAtVQWM_hj'
# [barrnap] Found: 16S_rRNA c1202 L=910/1585 1..910 - 16S ribosomal RNA (partial)
# [barrnap] Found 1 ribosomal RNA features.
# [barrnap] Sorting features and outputting GFF3...
# [barrnap] Writing hit sequences to: mags/14_gen_w_cov.3.fa_rrna.fa
# [barrnap] Running: bedtools getfasta -s -name+ -fo 'mags/14_gen_w_cov.3.fa_rrna.fa' -fi '/tmp/WAtVQWM_hj' -bed '/tmp/0tyCKg_Q5B'
# index file /tmp/WAtVQWM_hj.fai not found, generating...
# [barrnap] Done.
# [barrnap] This is barrnap 0.9
# [barrnap] Written by Torsten Seemann
# [barrnap] Obtained from https://github.com/tseemann/barrnap
# [barrnap] Detected operating system: linux
# [barrnap] Adding /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../binaries/linux to end of PATH
# [barrnap] Checking for dependencies:
# [barrnap] Found nhmmer - /home/gladkov2/anaconda3/envs/metabat/bin/nhmmer
# [barrnap] Found bedtools - /home/gladkov2/anaconda3/envs/metabat/bin/bedtools
# [barrnap] Will use 1 threads
# [barrnap] Setting evalue cutoff to 1e-06
# [barrnap] Will tag genes < 0.8 of expected length.
# [barrnap] Will reject genes < 0.25 of expected length.
# [barrnap] Using database: /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm
# [barrnap] Copying STDIN to a temporary file: /tmp/3W2t4GpGqu
# [barrnap] Scanning /tmp/3W2t4GpGqu for bac rRNA genes... please wait
# [barrnap] Command: nhmmer --cpu 1 -E 1e-06 --w_length 3878 -o /dev/null --tblout /dev/stdout '/home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm' '/tmp/3W2t4GpGqu'
# [barrnap] Found: 16S_rRNA c1379 L=1552/1585 16577..18128 + 16S ribosomal RNA
# [barrnap] Rejecting short 508 nt predicted 23S_rRNA. Adjust via --reject option.
# [barrnap] Found 1 ribosomal RNA features.
# [barrnap] Sorting features and outputting GFF3...
# [barrnap] Writing hit sequences to: mags/14_gen_w_cov.4.fa_rrna.fa
# [barrnap] Running: bedtools getfasta -s -name+ -fo 'mags/14_gen_w_cov.4.fa_rrna.fa' -fi '/tmp/3W2t4GpGqu' -bed '/tmp/QurpnTHLcE'
# index file /tmp/3W2t4GpGqu.fai not found, generating...
# [barrnap] Done.
# [barrnap] This is barrnap 0.9
# [barrnap] Written by Torsten Seemann
# [barrnap] Obtained from https://github.com/tseemann/barrnap
# [barrnap] Detected operating system: linux
# [barrnap] Adding /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../binaries/linux to end of PATH
# [barrnap] Checking for dependencies:
# [barrnap] Found nhmmer - /home/gladkov2/anaconda3/envs/metabat/bin/nhmmer
# [barrnap] Found bedtools - /home/gladkov2/anaconda3/envs/metabat/bin/bedtools
# [barrnap] Will use 1 threads
# [barrnap] Setting evalue cutoff to 1e-06
# [barrnap] Will tag genes < 0.8 of expected length.
# [barrnap] Will reject genes < 0.25 of expected length.
# [barrnap] Using database: /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm
# [barrnap] Copying STDIN to a temporary file: /tmp/BFteze9YqY
# [barrnap] Scanning /tmp/BFteze9YqY for bac rRNA genes... please wait
# [barrnap] Command: nhmmer --cpu 1 -E 1e-06 --w_length 3878 -o /dev/null --tblout /dev/stdout '/home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm' '/tmp/BFteze9YqY'
# [barrnap] Found: 16S_rRNA c15 L=1479/1585 3497..4975 - 16S ribosomal RNA
# [barrnap] Found: 16S_rRNA c140 L=472/1585 1..472 - 16S ribosomal RNA (partial)
# [barrnap] Found: 23S_rRNA c15 L=2714/3232 10..2723 - 23S ribosomal RNA
# [barrnap] Found 3 ribosomal RNA features.
# [barrnap] Sorting features and outputting GFF3...
# [barrnap] Writing hit sequences to: mags/14_gen_w_cov.5.fa_rrna.fa
# [barrnap] Running: bedtools getfasta -s -name+ -fo 'mags/14_gen_w_cov.5.fa_rrna.fa' -fi '/tmp/BFteze9YqY' -bed '/tmp/kXu89OnCQS'
# index file /tmp/BFteze9YqY.fai not found, generating...
# [barrnap] Done.
# [barrnap] This is barrnap 0.9
# [barrnap] Written by Torsten Seemann
# [barrnap] Obtained from https://github.com/tseemann/barrnap
# [barrnap] Detected operating system: linux
# [barrnap] Adding /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../binaries/linux to end of PATH
# [barrnap] Checking for dependencies:
# [barrnap] Found nhmmer - /home/gladkov2/anaconda3/envs/metabat/bin/nhmmer
# [barrnap] Found bedtools - /home/gladkov2/anaconda3/envs/metabat/bin/bedtools
# [barrnap] Will use 1 threads
# [barrnap] Setting evalue cutoff to 1e-06
# [barrnap] Will tag genes < 0.8 of expected length.
# [barrnap] Will reject genes < 0.25 of expected length.
# [barrnap] Using database: /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm
# [barrnap] Copying STDIN to a temporary file: /tmp/6ThO0MGvYr
# [barrnap] Scanning /tmp/6ThO0MGvYr for bac rRNA genes... please wait
# [barrnap] Command: nhmmer --cpu 1 -E 1e-06 --w_length 3878 -o /dev/null --tblout /dev/stdout '/home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm' '/tmp/6ThO0MGvYr'
# [barrnap] Found 0 ribosomal RNA features.
# [barrnap] Sorting features and outputting GFF3...
# [barrnap] Writing hit sequences to: mags/14_gen_w_cov.6.fa_rrna.fa
# [barrnap] Running: bedtools getfasta -s -name+ -fo 'mags/14_gen_w_cov.6.fa_rrna.fa' -fi '/tmp/6ThO0MGvYr' -bed '/tmp/ajg9jTotVb'
# index file /tmp/6ThO0MGvYr.fai not found, generating...
# [barrnap] Done.
# [barrnap] This is barrnap 0.9
# [barrnap] Written by Torsten Seemann
# [barrnap] Obtained from https://github.com/tseemann/barrnap
# [barrnap] Detected operating system: linux
# [barrnap] Adding /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../binaries/linux to end of PATH
# [barrnap] Checking for dependencies:
# [barrnap] Found nhmmer - /home/gladkov2/anaconda3/envs/metabat/bin/nhmmer
# [barrnap] Found bedtools - /home/gladkov2/anaconda3/envs/metabat/bin/bedtools
# [barrnap] Will use 1 threads
# [barrnap] Setting evalue cutoff to 1e-06
# [barrnap] Will tag genes < 0.8 of expected length.
# [barrnap] Will reject genes < 0.25 of expected length.
# [barrnap] Using database: /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm
# [barrnap] Copying STDIN to a temporary file: /tmp/1IdDX6En7n
# [barrnap] Scanning /tmp/1IdDX6En7n for bac rRNA genes... please wait
# [barrnap] Command: nhmmer --cpu 1 -E 1e-06 --w_length 3878 -o /dev/null --tblout /dev/stdout '/home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm' '/tmp/1IdDX6En7n'
# [barrnap] Rejecting short 587 nt predicted 23S_rRNA. Adjust via --reject option.
# [barrnap] Found: 5S_rRNA c1886 L=107/119 756..862 + 5S ribosomal RNA
# [barrnap] Found 1 ribosomal RNA features.
# [barrnap] Sorting features and outputting GFF3...
# [barrnap] Writing hit sequences to: mags/14_gen_w_cov.7.fa_rrna.fa
# [barrnap] Running: bedtools getfasta -s -name+ -fo 'mags/14_gen_w_cov.7.fa_rrna.fa' -fi '/tmp/1IdDX6En7n' -bed '/tmp/lJxY1sDO2U'
# index file /tmp/1IdDX6En7n.fai not found, generating...
# [barrnap] Done.
# [barrnap] This is barrnap 0.9
# [barrnap] Written by Torsten Seemann
# [barrnap] Obtained from https://github.com/tseemann/barrnap
# [barrnap] Detected operating system: linux
# [barrnap] Adding /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../binaries/linux to end of PATH
# [barrnap] Checking for dependencies:
# [barrnap] Found nhmmer - /home/gladkov2/anaconda3/envs/metabat/bin/nhmmer
# [barrnap] Found bedtools - /home/gladkov2/anaconda3/envs/metabat/bin/bedtools
# [barrnap] Will use 1 threads
# [barrnap] Setting evalue cutoff to 1e-06
# [barrnap] Will tag genes < 0.8 of expected length.
# [barrnap] Will reject genes < 0.25 of expected length.
# [barrnap] Using database: /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm
# [barrnap] Copying STDIN to a temporary file: /tmp/qD_mIJYdwI
# [barrnap] Scanning /tmp/qD_mIJYdwI for bac rRNA genes... please wait
# [barrnap] Command: nhmmer --cpu 1 -E 1e-06 --w_length 3878 -o /dev/null --tblout /dev/stdout '/home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm' '/tmp/qD_mIJYdwI'
# [barrnap] Found: 16S_rRNA c1203 L=1526/1585 606..2131 - 16S ribosomal RNA
# [barrnap] Found: 16S_rRNA c1409 L=1523/1585 3088..4610 - 16S ribosomal RNA
# [barrnap] Found: 16S_rRNA c1887 L=1236/1585 2..1237 + 16S ribosomal RNA (partial)
# [barrnap] Found: 23S_rRNA c1887 L=2874/3232 1894..4767 + 23S ribosomal RNA
# [barrnap] Found: 23S_rRNA c1200 L=2416/3232 51512..53927 - 23S ribosomal RNA (partial)
# [barrnap] Found: 23S_rRNA c1409 L=2667/3232 2..2668 - 23S ribosomal RNA
# [barrnap] Found: 5S_rRNA c1887 L=112/119 4941..5052 + 5S ribosomal RNA
# [barrnap] Found: 5S_rRNA c1200 L=107/119 51240..51346 - 5S ribosomal RNA
# [barrnap] Found 8 ribosomal RNA features.
# [barrnap] Sorting features and outputting GFF3...
# [barrnap] Writing hit sequences to: mags/14_gen_w_cov.8.fa_rrna.fa
# [barrnap] Running: bedtools getfasta -s -name+ -fo 'mags/14_gen_w_cov.8.fa_rrna.fa' -fi '/tmp/qD_mIJYdwI' -bed '/tmp/pMMsBYLoKc'
# index file /tmp/qD_mIJYdwI.fai not found, generating...
# [barrnap] Done.
# [barrnap] This is barrnap 0.9
# [barrnap] Written by Torsten Seemann
# [barrnap] Obtained from https://github.com/tseemann/barrnap
# [barrnap] Detected operating system: linux
# [barrnap] Adding /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../binaries/linux to end of PATH
# [barrnap] Checking for dependencies:
# [barrnap] Found nhmmer - /home/gladkov2/anaconda3/envs/metabat/bin/nhmmer
# [barrnap] Found bedtools - /home/gladkov2/anaconda3/envs/metabat/bin/bedtools
# [barrnap] Will use 1 threads
# [barrnap] Setting evalue cutoff to 1e-06
# [barrnap] Will tag genes < 0.8 of expected length.
# [barrnap] Will reject genes < 0.25 of expected length.
# [barrnap] Using database: /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm
# [barrnap] Copying STDIN to a temporary file: /tmp/4oyzx9bZhQ
# [barrnap] Scanning /tmp/4oyzx9bZhQ for bac rRNA genes... please wait
# [barrnap] Command: nhmmer --cpu 1 -E 1e-06 --w_length 3878 -o /dev/null --tblout /dev/stdout '/home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm' '/tmp/4oyzx9bZhQ'
# [barrnap] Found 0 ribosomal RNA features.
# [barrnap] Sorting features and outputting GFF3...
# [barrnap] Writing hit sequences to: mags/14_gen_w_cov.9.fa_rrna.fa
# [barrnap] Running: bedtools getfasta -s -name+ -fo 'mags/14_gen_w_cov.9.fa_rrna.fa' -fi '/tmp/4oyzx9bZhQ' -bed '/tmp/__ddIAeODe'
# index file /tmp/4oyzx9bZhQ.fai not found, generating...
# [barrnap] Done.
# [barrnap] This is barrnap 0.9
# [barrnap] Written by Torsten Seemann
# [barrnap] Obtained from https://github.com/tseemann/barrnap
# [barrnap] Detected operating system: linux
# [barrnap] Adding /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../binaries/linux to end of PATH
# [barrnap] Checking for dependencies:
# [barrnap] Found nhmmer - /home/gladkov2/anaconda3/envs/metabat/bin/nhmmer
# [barrnap] Found bedtools - /home/gladkov2/anaconda3/envs/metabat/bin/bedtools
# [barrnap] Will use 1 threads
# [barrnap] Setting evalue cutoff to 1e-06
# [barrnap] Will tag genes < 0.8 of expected length.
# [barrnap] Will reject genes < 0.25 of expected length.
# [barrnap] Using database: /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm
# [barrnap] Copying STDIN to a temporary file: /tmp/iUyBlCX0NO
# [barrnap] Scanning /tmp/iUyBlCX0NO for bac rRNA genes... please wait
# [barrnap] Command: nhmmer --cpu 1 -E 1e-06 --w_length 3878 -o /dev/null --tblout /dev/stdout '/home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm' '/tmp/iUyBlCX0NO'
# [barrnap] Found: 16S_rRNA c426 L=1552/1585 1001180..1002731 + 16S ribosomal RNA
# [barrnap] Found: 23S_rRNA c426 L=2995/3232 1003395..1006389 + 23S ribosomal RNA
# [barrnap] Rejecting short 156 nt predicted 23S_rRNA. Adjust via --reject option.
# [barrnap] Found: 5S_rRNA c426 L=110/119 1006561..1006670 + 5S ribosomal RNA
# [barrnap] Found: 5S_rRNA c614 L=110/119 329..438 + 5S ribosomal RNA
# [barrnap] Found 4 ribosomal RNA features.
# [barrnap] Sorting features and outputting GFF3...
# [barrnap] Writing hit sequences to: mags/26_gen_w_cov.1.fa_rrna.fa
# [barrnap] Running: bedtools getfasta -s -name+ -fo 'mags/26_gen_w_cov.1.fa_rrna.fa' -fi '/tmp/iUyBlCX0NO' -bed '/tmp/d2mfO3gghE'
# index file /tmp/iUyBlCX0NO.fai not found, generating...
# [barrnap] Done.
# [barrnap] This is barrnap 0.9
# [barrnap] Written by Torsten Seemann
# [barrnap] Obtained from https://github.com/tseemann/barrnap
# [barrnap] Detected operating system: linux
# [barrnap] Adding /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../binaries/linux to end of PATH
# [barrnap] Checking for dependencies:
# [barrnap] Found nhmmer - /home/gladkov2/anaconda3/envs/metabat/bin/nhmmer
# [barrnap] Found bedtools - /home/gladkov2/anaconda3/envs/metabat/bin/bedtools
# [barrnap] Will use 1 threads
# [barrnap] Setting evalue cutoff to 1e-06
# [barrnap] Will tag genes < 0.8 of expected length.
# [barrnap] Will reject genes < 0.25 of expected length.
# [barrnap] Using database: /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm
# [barrnap] Copying STDIN to a temporary file: /tmp/_yRbEphFIw
# [barrnap] Scanning /tmp/_yRbEphFIw for bac rRNA genes... please wait
# [barrnap] Command: nhmmer --cpu 1 -E 1e-06 --w_length 3878 -o /dev/null --tblout /dev/stdout '/home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm' '/tmp/_yRbEphFIw'
# [barrnap] Found: 16S_rRNA c1382 L=1480/1585 225..1704 + 16S ribosomal RNA
# [barrnap] Found: 23S_rRNA c1382 L=2712/3232 2384..5095 + 23S ribosomal RNA
# [barrnap] Found: 23S_rRNA c1381 L=1092/3232 1..1092 + 23S ribosomal RNA (partial)
# [barrnap] Found 3 ribosomal RNA features.
# [barrnap] Sorting features and outputting GFF3...
# [barrnap] Writing hit sequences to: mags/26_gen_w_cov.10.fa_rrna.fa
# [barrnap] Running: bedtools getfasta -s -name+ -fo 'mags/26_gen_w_cov.10.fa_rrna.fa' -fi '/tmp/_yRbEphFIw' -bed '/tmp/vtN0fREydx'
# index file /tmp/_yRbEphFIw.fai not found, generating...
# [barrnap] Done.
# [barrnap] This is barrnap 0.9
# [barrnap] Written by Torsten Seemann
# [barrnap] Obtained from https://github.com/tseemann/barrnap
# [barrnap] Detected operating system: linux
# [barrnap] Adding /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../binaries/linux to end of PATH
# [barrnap] Checking for dependencies:
# [barrnap] Found nhmmer - /home/gladkov2/anaconda3/envs/metabat/bin/nhmmer
# [barrnap] Found bedtools - /home/gladkov2/anaconda3/envs/metabat/bin/bedtools
# [barrnap] Will use 1 threads
# [barrnap] Setting evalue cutoff to 1e-06
# [barrnap] Will tag genes < 0.8 of expected length.
# [barrnap] Will reject genes < 0.25 of expected length.
# [barrnap] Using database: /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm
# [barrnap] Copying STDIN to a temporary file: /tmp/ITbR_s6Hwd
# [barrnap] Scanning /tmp/ITbR_s6Hwd for bac rRNA genes... please wait
# [barrnap] Command: nhmmer --cpu 1 -E 1e-06 --w_length 3878 -o /dev/null --tblout /dev/stdout '/home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm' '/tmp/ITbR_s6Hwd'
# [barrnap] Found: 16S_rRNA c121 L=1527/1585 672735..674261 - 16S ribosomal RNA
# [barrnap] Found: 16S_rRNA c1146 L=1526/1585 243..1768 - 16S ribosomal RNA
# [barrnap] Found: 23S_rRNA c121 L=2873/3232 668336..671208 - 23S ribosomal RNA
# [barrnap] Found: 23S_rRNA c182 L=2873/3232 470..3342 + 23S ribosomal RNA
# [barrnap] Found: 23S_rRNA c113 L=2526/3232 7..2532 + 23S ribosomal RNA (partial)
# [barrnap] Found: 5S_rRNA c113 L=111/119 2745..2855 + 5S ribosomal RNA
# [barrnap] Found: 5S_rRNA c121 L=111/119 668013..668123 - 5S ribosomal RNA
# [barrnap] Found: 5S_rRNA c182 L=111/119 3555..3665 + 5S ribosomal RNA
# [barrnap] Found 8 ribosomal RNA features.
# [barrnap] Sorting features and outputting GFF3...
# [barrnap] Writing hit sequences to: mags/26_gen_w_cov.11.fa_rrna.fa
# [barrnap] Running: bedtools getfasta -s -name+ -fo 'mags/26_gen_w_cov.11.fa_rrna.fa' -fi '/tmp/ITbR_s6Hwd' -bed '/tmp/1YLpdQG1CH'
# index file /tmp/ITbR_s6Hwd.fai not found, generating...
# [barrnap] Done.
# [barrnap] This is barrnap 0.9
# [barrnap] Written by Torsten Seemann
# [barrnap] Obtained from https://github.com/tseemann/barrnap
# [barrnap] Detected operating system: linux
# [barrnap] Adding /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../binaries/linux to end of PATH
# [barrnap] Checking for dependencies:
# [barrnap] Found nhmmer - /home/gladkov2/anaconda3/envs/metabat/bin/nhmmer
# [barrnap] Found bedtools - /home/gladkov2/anaconda3/envs/metabat/bin/bedtools
# [barrnap] Will use 1 threads
# [barrnap] Setting evalue cutoff to 1e-06
# [barrnap] Will tag genes < 0.8 of expected length.
# [barrnap] Will reject genes < 0.25 of expected length.
# [barrnap] Using database: /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm
# [barrnap] Copying STDIN to a temporary file: /tmp/DE_hKA4h9P
# [barrnap] Scanning /tmp/DE_hKA4h9P for bac rRNA genes... please wait
# [barrnap] Command: nhmmer --cpu 1 -E 1e-06 --w_length 3878 -o /dev/null --tblout /dev/stdout '/home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm' '/tmp/DE_hKA4h9P'
# [barrnap] Found: 16S_rRNA c558 L=1478/1585 124237..125714 + 16S ribosomal RNA
# [barrnap] Found: 16S_rRNA c203 L=1486/1585 123721..125206 + 16S ribosomal RNA
# [barrnap] Found: 23S_rRNA c558 L=2721/3232 126388..129108 + 23S ribosomal RNA
# [barrnap] Found: 23S_rRNA c109 L=1062/3232 1..1062 + 23S ribosomal RNA (partial)
# [barrnap] Rejecting short 142 nt predicted 23S_rRNA. Adjust via --reject option.
# [barrnap] Found: 5S_rRNA c558 L=110/119 129240..129349 + 5S ribosomal RNA
# [barrnap] Found 5 ribosomal RNA features.
# [barrnap] Sorting features and outputting GFF3...
# [barrnap] Writing hit sequences to: mags/26_gen_w_cov.12.fa_rrna.fa
# [barrnap] Running: bedtools getfasta -s -name+ -fo 'mags/26_gen_w_cov.12.fa_rrna.fa' -fi '/tmp/DE_hKA4h9P' -bed '/tmp/YT7yB_zjve'
# index file /tmp/DE_hKA4h9P.fai not found, generating...
# [barrnap] Done.
# [barrnap] This is barrnap 0.9
# [barrnap] Written by Torsten Seemann
# [barrnap] Obtained from https://github.com/tseemann/barrnap
# [barrnap] Detected operating system: linux
# [barrnap] Adding /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../binaries/linux to end of PATH
# [barrnap] Checking for dependencies:
# [barrnap] Found nhmmer - /home/gladkov2/anaconda3/envs/metabat/bin/nhmmer
# [barrnap] Found bedtools - /home/gladkov2/anaconda3/envs/metabat/bin/bedtools
# [barrnap] Will use 1 threads
# [barrnap] Setting evalue cutoff to 1e-06
# [barrnap] Will tag genes < 0.8 of expected length.
# [barrnap] Will reject genes < 0.25 of expected length.
# [barrnap] Using database: /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm
# [barrnap] Copying STDIN to a temporary file: /tmp/ryO8REVJIr
# [barrnap] Scanning /tmp/ryO8REVJIr for bac rRNA genes... please wait
# ...
# [barrnap] Using database: /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm
# [barrnap] Copying STDIN to a temporary file: /tmp/UpGcCHlX7o
# [barrnap] Scanning /tmp/UpGcCHlX7o for bac rRNA genes... please wait
# [barrnap] Command: nhmmer --cpu 1 -E 1e-06 --w_length 3878 -o /dev/null --tblout /dev/stdout '/home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm' '/tmp/UpGcCHlX7o'
# [barrnap] Found 0 ribosomal RNA features.
# [barrnap] Sorting features and outputting GFF3...
# [barrnap] Writing hit sequences to: mags/46_gen_w_cov.3.fa_rrna.fa
# [barrnap] Running: bedtools getfasta -s -name+ -fo 'mags/46_gen_w_cov.3.fa_rrna.fa' -fi '/tmp/UpGcCHlX7o' -bed '/tmp/DT5w8GUQmi'
# index file /tmp/UpGcCHlX7o.fai not found, generating...
# [barrnap] Done.
# [barrnap] This is barrnap 0.9
# [barrnap] Written by Torsten Seemann
# [barrnap] Obtained from https://github.com/tseemann/barrnap
# [barrnap] Detected operating system: linux
# [barrnap] Adding /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../binaries/linux to end of PATH
# [barrnap] Checking for dependencies:
# [barrnap] Found nhmmer - /home/gladkov2/anaconda3/envs/metabat/bin/nhmmer
# [barrnap] Found bedtools - /home/gladkov2/anaconda3/envs/metabat/bin/bedtools
# [barrnap] Will use 1 threads
# [barrnap] Setting evalue cutoff to 1e-06
# [barrnap] Will tag genes < 0.8 of expected length.
# [barrnap] Will reject genes < 0.25 of expected length.
# [barrnap] Using database: /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm
# [barrnap] Copying STDIN to a temporary file: /tmp/CkaHrjaWZH
# [barrnap] Scanning /tmp/CkaHrjaWZH for bac rRNA genes... please wait
# [barrnap] Command: nhmmer --cpu 1 -E 1e-06 --w_length 3878 -o /dev/null --tblout /dev/stdout '/home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm' '/tmp/CkaHrjaWZH'
# [barrnap] Found: 16S_rRNA c208 L=1476/1585 578129..579604 - 16S ribosomal RNA
# [barrnap] Found: 23S_rRNA c208 L=2889/3232 574216..577104 - 23S ribosomal RNA
# [barrnap] Found: 5S_rRNA c208 L=110/119 574023..574132 - 5S ribosomal RNA
# [barrnap] Found 3 ribosomal RNA features.
# [barrnap] Sorting features and outputting GFF3...
# [barrnap] Writing hit sequences to: mags/46_gen_w_cov.30.fa_rrna.fa
# [barrnap] Running: bedtools getfasta -s -name+ -fo 'mags/46_gen_w_cov.30.fa_rrna.fa' -fi '/tmp/CkaHrjaWZH' -bed '/tmp/nnfB3EcyxU'
# index file /tmp/CkaHrjaWZH.fai not found, generating...
# [barrnap] Done.
# [barrnap] This is barrnap 0.9
# [barrnap] Written by Torsten Seemann
# [barrnap] Obtained from https://github.com/tseemann/barrnap
# [barrnap] Detected operating system: linux
# [barrnap] Adding /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../binaries/linux to end of PATH
# [barrnap] Checking for dependencies:
# [barrnap] Found nhmmer - /home/gladkov2/anaconda3/envs/metabat/bin/nhmmer
# [barrnap] Found bedtools - /home/gladkov2/anaconda3/envs/metabat/bin/bedtools
# [barrnap] Will use 1 threads
# [barrnap] Setting evalue cutoff to 1e-06
# [barrnap] Will tag genes < 0.8 of expected length.
# [barrnap] Will reject genes < 0.25 of expected length.
# [barrnap] Using database: /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm
# [barrnap] Copying STDIN to a temporary file: /tmp/mCi_N8nSHG
# [barrnap] Scanning /tmp/mCi_N8nSHG for bac rRNA genes... please wait
# [barrnap] Command: nhmmer --cpu 1 -E 1e-06 --w_length 3878 -o /dev/null --tblout /dev/stdout '/home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm' '/tmp/mCi_N8nSHG'
# [barrnap] Found: 16S_rRNA c12 L=1515/1585 2305542..2307056 + 16S ribosomal RNA
# [barrnap] Found: 16S_rRNA c12 L=1516/1585 1716909..1718424 + 16S ribosomal RNA
# [barrnap] Found: 23S_rRNA c12 L=3103/3232 1718850..1721952 + 23S ribosomal RNA
# [barrnap] Found: 23S_rRNA c12 L=3103/3232 2307482..2310584 + 23S ribosomal RNA
# [barrnap] Found: 5S_rRNA c12 L=110/119 1722047..1722156 + 5S ribosomal RNA
# [barrnap] Found: 5S_rRNA c12 L=110/119 2310678..2310787 + 5S ribosomal RNA
# [barrnap] Found 6 ribosomal RNA features.
# [barrnap] Sorting features and outputting GFF3...
# [barrnap] Writing hit sequences to: mags/46_gen_w_cov.31.fa_rrna.fa
# [barrnap] Running: bedtools getfasta -s -name+ -fo 'mags/46_gen_w_cov.31.fa_rrna.fa' -fi '/tmp/mCi_N8nSHG' -bed '/tmp/8HgamIsFQz'
# index file /tmp/mCi_N8nSHG.fai not found, generating...
# [barrnap] Done.
# [barrnap] This is barrnap 0.9
# [barrnap] Written by Torsten Seemann
# [barrnap] Obtained from https://github.com/tseemann/barrnap
# [barrnap] Detected operating system: linux
# [barrnap] Adding /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../binaries/linux to end of PATH
# [barrnap] Checking for dependencies:
# [barrnap] Found nhmmer - /home/gladkov2/anaconda3/envs/metabat/bin/nhmmer
# [barrnap] Found bedtools - /home/gladkov2/anaconda3/envs/metabat/bin/bedtools
# [barrnap] Will use 1 threads
# [barrnap] Setting evalue cutoff to 1e-06
# [barrnap] Will tag genes < 0.8 of expected length.
# [barrnap] Will reject genes < 0.25 of expected length.
# [barrnap] Using database: /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm
# [barrnap] Copying STDIN to a temporary file: /tmp/Tob7sHZWmy
# [barrnap] Scanning /tmp/Tob7sHZWmy for bac rRNA genes... please wait
# [barrnap] Command: nhmmer --cpu 1 -E 1e-06 --w_length 3878 -o /dev/null --tblout /dev/stdout '/home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm' '/tmp/Tob7sHZWmy'
# [barrnap] Found: 16S_rRNA c1206 L=1482/1585 116335..117816 + 16S ribosomal RNA
# [barrnap] Found 1 ribosomal RNA features.
# [barrnap] Sorting features and outputting GFF3...
# [barrnap] Writing hit sequences to: mags/46_gen_w_cov.32.fa_rrna.fa
# [barrnap] Running: bedtools getfasta -s -name+ -fo 'mags/46_gen_w_cov.32.fa_rrna.fa' -fi '/tmp/Tob7sHZWmy' -bed '/tmp/mgAax5dTWN'
# index file /tmp/Tob7sHZWmy.fai not found, generating...
# [barrnap] Done.
# [barrnap] This is barrnap 0.9
# [barrnap] Written by Torsten Seemann
# [barrnap] Obtained from https://github.com/tseemann/barrnap
# [barrnap] Detected operating system: linux
# [barrnap] Adding /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../binaries/linux to end of PATH
# [barrnap] Checking for dependencies:
# [barrnap] Found nhmmer - /home/gladkov2/anaconda3/envs/metabat/bin/nhmmer
# [barrnap] Found bedtools - /home/gladkov2/anaconda3/envs/metabat/bin/bedtools
# [barrnap] Will use 1 threads
# [barrnap] Setting evalue cutoff to 1e-06
# [barrnap] Will tag genes < 0.8 of expected length.
# [barrnap] Will reject genes < 0.25 of expected length.
# [barrnap] Using database: /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm
# [barrnap] Copying STDIN to a temporary file: /tmp/GYywLXeFjr
# [barrnap] Scanning /tmp/GYywLXeFjr for bac rRNA genes... please wait
# [barrnap] Command: nhmmer --cpu 1 -E 1e-06 --w_length 3878 -o /dev/null --tblout /dev/stdout '/home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm' '/tmp/GYywLXeFjr'
# [barrnap] Found: 16S_rRNA c241 L=1543/1585 1283..2825 - 16S ribosomal RNA
# [barrnap] Found: 16S_rRNA c233 L=1544/1585 2317..3860 - 16S ribosomal RNA
# [barrnap] Found: 23S_rRNA c233 L=2045/3232 1..2045 - 23S ribosomal RNA (partial)
# [barrnap] Found: 23S_rRNA c332 L=1599/3232 2..1600 + 23S ribosomal RNA (partial)
# [barrnap] Found: 23S_rRNA c241 L=942/3232 5..946 - 23S ribosomal RNA (partial)
# [barrnap] Found 5 ribosomal RNA features.
# [barrnap] Sorting features and outputting GFF3...
# [barrnap] Writing hit sequences to: mags/46_gen_w_cov.4.fa_rrna.fa
# [barrnap] Running: bedtools getfasta -s -name+ -fo 'mags/46_gen_w_cov.4.fa_rrna.fa' -fi '/tmp/GYywLXeFjr' -bed '/tmp/EPzbfsIkkc'
# index file /tmp/GYywLXeFjr.fai not found, generating...
# [barrnap] Done.
# [barrnap] This is barrnap 0.9
# [barrnap] Written by Torsten Seemann
# [barrnap] Obtained from https://github.com/tseemann/barrnap
# [barrnap] Detected operating system: linux
# [barrnap] Adding /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../binaries/linux to end of PATH
# [barrnap] Checking for dependencies:
# [barrnap] Found nhmmer - /home/gladkov2/anaconda3/envs/metabat/bin/nhmmer
# [barrnap] Found bedtools - /home/gladkov2/anaconda3/envs/metabat/bin/bedtools
# [barrnap] Will use 1 threads
# [barrnap] Setting evalue cutoff to 1e-06
# [barrnap] Will tag genes < 0.8 of expected length.
# [barrnap] Will reject genes < 0.25 of expected length.
# [barrnap] Using database: /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm
# [barrnap] Copying STDIN to a temporary file: /tmp/8liMEIvuBm
# [barrnap] Scanning /tmp/8liMEIvuBm for bac rRNA genes... please wait
# [barrnap] Command: nhmmer --cpu 1 -E 1e-06 --w_length 3878 -o /dev/null --tblout /dev/stdout '/home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm' '/tmp/8liMEIvuBm'
# [barrnap] Found: 16S_rRNA c222 L=1481/1585 509960..511440 - 16S ribosomal RNA
# [barrnap] Found: 23S_rRNA c222 L=2713/3232 506563..509275 - 23S ribosomal RNA
# [barrnap] Found 2 ribosomal RNA features.
# [barrnap] Sorting features and outputting GFF3...
# [barrnap] Writing hit sequences to: mags/46_gen_w_cov.5.fa_rrna.fa
# [barrnap] Running: bedtools getfasta -s -name+ -fo 'mags/46_gen_w_cov.5.fa_rrna.fa' -fi '/tmp/8liMEIvuBm' -bed '/tmp/8W8WuDMjeY'
# index file /tmp/8liMEIvuBm.fai not found, generating...
# [barrnap] Done.
# [barrnap] This is barrnap 0.9
# [barrnap] Written by Torsten Seemann
# [barrnap] Obtained from https://github.com/tseemann/barrnap
# [barrnap] Detected operating system: linux
# [barrnap] Adding /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../binaries/linux to end of PATH
# [barrnap] Checking for dependencies:
# [barrnap] Found nhmmer - /home/gladkov2/anaconda3/envs/metabat/bin/nhmmer
# [barrnap] Found bedtools - /home/gladkov2/anaconda3/envs/metabat/bin/bedtools
# [barrnap] Will use 1 threads
# [barrnap] Setting evalue cutoff to 1e-06
# [barrnap] Will tag genes < 0.8 of expected length.
# [barrnap] Will reject genes < 0.25 of expected length.
# [barrnap] Using database: /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm
# [barrnap] Copying STDIN to a temporary file: /tmp/9ZszkEBdoB
# [barrnap] Scanning /tmp/9ZszkEBdoB for bac rRNA genes... please wait
# [barrnap] Command: nhmmer --cpu 1 -E 1e-06 --w_length 3878 -o /dev/null --tblout /dev/stdout '/home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm' '/tmp/9ZszkEBdoB'
# [barrnap] Found: 16S_rRNA c59 L=1486/1585 275..1760 + 16S ribosomal RNA
# [barrnap] Found: 16S_rRNA c1186 L=1493/1585 55333..56825 + 16S ribosomal RNA
# [barrnap] Found: 16S_rRNA c57 L=1404/1585 6..1409 + 16S ribosomal RNA
# [barrnap] Found: 23S_rRNA c57 L=2737/3232 1977..4713 + 23S ribosomal RNA
# [barrnap] Found: 23S_rRNA c59 L=2748/3232 2329..5076 + 23S ribosomal RNA
# [barrnap] Found: 23S_rRNA c1186 L=2734/3232 57105..59838 + 23S ribosomal RNA
# [barrnap] Found: 23S_rRNA c55 L=2741/3232 361..3101 + 23S ribosomal RNA
# [barrnap] Found: 23S_rRNA c58 L=2672/3232 3..2674 + 23S ribosomal RNA
# [barrnap] Found: 23S_rRNA c70 L=1905/3232 1..1905 + 23S ribosomal RNA (partial)
# [barrnap] Found: 5S_rRNA c57 L=110/119 4848..4957 + 5S ribosomal RNA
# [barrnap] Found: 5S_rRNA c58 L=110/119 2808..2917 + 5S ribosomal RNA
# [barrnap] Found: 5S_rRNA c59 L=110/119 5210..5319 + 5S ribosomal RNA
# [barrnap] Found: 5S_rRNA c70 L=110/119 2039..2148 + 5S ribosomal RNA
# [barrnap] Found: 5S_rRNA c55 L=111/119 3239..3349 + 5S ribosomal RNA
# [barrnap] Found 14 ribosomal RNA features.
# [barrnap] Sorting features and outputting GFF3...
# [barrnap] Writing hit sequences to: mags/46_gen_w_cov.6.fa_rrna.fa
# [barrnap] Running: bedtools getfasta -s -name+ -fo 'mags/46_gen_w_cov.6.fa_rrna.fa' -fi '/tmp/9ZszkEBdoB' -bed '/tmp/CiXAn23m6l'
# index file /tmp/9ZszkEBdoB.fai not found, generating...
# [barrnap] Done.
# [barrnap] This is barrnap 0.9
# [barrnap] Written by Torsten Seemann
# [barrnap] Obtained from https://github.com/tseemann/barrnap
# [barrnap] Detected operating system: linux
# [barrnap] Adding /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../binaries/linux to end of PATH
# [barrnap] Checking for dependencies:
# [barrnap] Found nhmmer - /home/gladkov2/anaconda3/envs/metabat/bin/nhmmer
# [barrnap] Found bedtools - /home/gladkov2/anaconda3/envs/metabat/bin/bedtools
# [barrnap] Will use 1 threads
# [barrnap] Setting evalue cutoff to 1e-06
# [barrnap] Will tag genes < 0.8 of expected length.
# [barrnap] Will reject genes < 0.25 of expected length.
# [barrnap] Using database: /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm
# [barrnap] Copying STDIN to a temporary file: /tmp/UlsvzwqBEe
# [barrnap] Scanning /tmp/UlsvzwqBEe for bac rRNA genes... please wait
# [barrnap] Command: nhmmer --cpu 1 -E 1e-06 --w_length 3878 -o /dev/null --tblout /dev/stdout '/home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm' '/tmp/UlsvzwqBEe'
# [barrnap] Found: 16S_rRNA c1525 L=570/1585 1..570 + 16S ribosomal RNA (partial)
# [barrnap] Found: 23S_rRNA c1525 L=2727/3232 1223..3949 + 23S ribosomal RNA
# [barrnap] Found: 5S_rRNA c1525 L=110/119 4039..4148 + 5S ribosomal RNA
# [barrnap] Found 3 ribosomal RNA features.
# [barrnap] Sorting features and outputting GFF3...
# [barrnap] Writing hit sequences to: mags/46_gen_w_cov.7.fa_rrna.fa
# [barrnap] Running: bedtools getfasta -s -name+ -fo 'mags/46_gen_w_cov.7.fa_rrna.fa' -fi '/tmp/UlsvzwqBEe' -bed '/tmp/5kpOGcU6K8'
# index file /tmp/UlsvzwqBEe.fai not found, generating...
# [barrnap] Done.
# [barrnap] This is barrnap 0.9
# [barrnap] Written by Torsten Seemann
# [barrnap] Obtained from https://github.com/tseemann/barrnap
# [barrnap] Detected operating system: linux
# [barrnap] Adding /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../binaries/linux to end of PATH
# [barrnap] Checking for dependencies:
# [barrnap] Found nhmmer - /home/gladkov2/anaconda3/envs/metabat/bin/nhmmer
# [barrnap] Found bedtools - /home/gladkov2/anaconda3/envs/metabat/bin/bedtools
# [barrnap] Will use 1 threads
# [barrnap] Setting evalue cutoff to 1e-06
# [barrnap] Will tag genes < 0.8 of expected length.
# [barrnap] Will reject genes < 0.25 of expected length.
# [barrnap] Using database: /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm
# [barrnap] Copying STDIN to a temporary file: /tmp/4UTqY2TU9E
# [barrnap] Scanning /tmp/4UTqY2TU9E for bac rRNA genes... please wait
# [barrnap] Command: nhmmer --cpu 1 -E 1e-06 --w_length 3878 -o /dev/null --tblout /dev/stdout '/home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm' '/tmp/4UTqY2TU9E'
# [barrnap] Found 0 ribosomal RNA features.
# [barrnap] Sorting features and outputting GFF3...
# [barrnap] Writing hit sequences to: mags/46_gen_w_cov.8.fa_rrna.fa
# [barrnap] Running: bedtools getfasta -s -name+ -fo 'mags/46_gen_w_cov.8.fa_rrna.fa' -fi '/tmp/4UTqY2TU9E' -bed '/tmp/s2xZvzszqo'
# index file /tmp/4UTqY2TU9E.fai not found, generating...
# [barrnap] Done.
# [barrnap] This is barrnap 0.9
# [barrnap] Written by Torsten Seemann
# [barrnap] Obtained from https://github.com/tseemann/barrnap
# [barrnap] Detected operating system: linux
# [barrnap] Adding /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../binaries/linux to end of PATH
# [barrnap] Checking for dependencies:
# [barrnap] Found nhmmer - /home/gladkov2/anaconda3/envs/metabat/bin/nhmmer
# [barrnap] Found bedtools - /home/gladkov2/anaconda3/envs/metabat/bin/bedtools
# [barrnap] Will use 1 threads
# [barrnap] Setting evalue cutoff to 1e-06
# [barrnap] Will tag genes < 0.8 of expected length.
# [barrnap] Will reject genes < 0.25 of expected length.
# [barrnap] Using database: /home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm
# [barrnap] Copying STDIN to a temporary file: /tmp/glpXIXNE1p
# [barrnap] Scanning /tmp/glpXIXNE1p for bac rRNA genes... please wait
# [barrnap] Command: nhmmer --cpu 1 -E 1e-06 --w_length 3878 -o /dev/null --tblout /dev/stdout '/home/gladkov2/anaconda3/envs/metabat/lib/barrnap/bin/../db/bac.hmm' '/tmp/glpXIXNE1p'
# [barrnap] Found 0 ribosomal RNA features.
# [barrnap] Sorting features and outputting GFF3...
# [barrnap] Writing hit sequences to: mags/46_gen_w_cov.9.fa_rrna.fa
# [barrnap] Running: bedtools getfasta -s -name+ -fo 'mags/46_gen_w_cov.9.fa_rrna.fa' -fi '/tmp/glpXIXNE1p' -bed '/tmp/ablTVnGfhy'
# index file /tmp/glpXIXNE1p.fai not found, generating...
# [barrnap] Done.

# %%
# !rm -rf mags

# %%
for f in d:
    # !metabat2 -i $f\.fq -o mags/$f\_gen_cov -a  $f\_depth.txt
# Out:
# MetaBAT 2 (v2.12.1) using minContig 2500, minCV 1.0, minCVSum 1.0, maxP 95%, minS 60, and maxEdges 200.
# 2 bins (4266870 bases in total) formed.
# MetaBAT 2 (v2.12.1) using minContig 2500, minCV 1.0, minCVSum 1.0, maxP 95%, minS 60, and maxEdges 200.
# 0 bins (0 bases in total) formed.
# MetaBAT 2 (v2.12.1) using minContig 2500, minCV 1.0, minCVSum 1.0, maxP 95%, minS 60, and maxEdges 200.
# 0 bins (0 bases in total) formed.
# MetaBAT 2 (v2.12.1) using minContig 2500, minCV 1.0, minCVSum 1.0, maxP 95%, minS 60, and maxEdges 200.
# 3 bins (12204608 bases in total) formed.

# %%
checkm lineage_wf -x fa  -f checkm/N2_MAGs_checkm.tab -t 50 metabat2_bins_3/ out/
checkm qa ./out/lineage.ms ./out -o 2 -f res --tab_table -t 20

# %%
# !checkm lineage_wf -h
# Out:
# usage: checkm lineage_wf [-h] [-r] [--ali] [--nt] [-g] [-u UNIQUE] [-m MULTI]
#                          [--force_domain] [--no_refinement]
#                          [--individual_markers] [--skip_adj_correction]
#                          [--skip_pseudogene_correction]
#                          [--aai_strain AAI_STRAIN] [-a ALIGNMENT_FILE]
#                          [--ignore_thresholds] [-e E_VALUE] [-l LENGTH]
#                          [-f FILE] [--tab_table] [-x EXTENSION] [-t THREADS]
#                          [--pplacer_threads PPLACER_THREADS] [-q]
#                          [--tmpdir TMPDIR]
#                          bin_dir output_dir
#
# Runs tree, lineage_set, analyze, qa
#
# positional arguments:
#   bin_dir               directory containing bins (fasta format)
#   output_dir            directory to write output files
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -r, --reduced_tree    use reduced tree (requires <16GB of memory) for determining lineage of each bin
#   --ali                 generate HMMER alignment file for each bin
#   --nt                  generate nucleotide gene sequences for each bin
#   -g, --genes           bins contain genes as amino acids instead of nucleotide contigs
#   -u, --unique UNIQUE   minimum number of unique phylogenetic markers required to use lineage-specific marker set (default: 10)
#   -m, --multi MULTI     maximum number of multi-copy phylogenetic markers before defaulting to domain-level marker set (default: 10)
#   --force_domain        use domain-level sets for all bins
#   --no_refinement       do not perform lineage-specific marker set refinement
#   --individual_markers  treat marker as independent (i.e., ignore co-located set structure)
#   --skip_adj_correction
#                         do not exclude adjacent marker genes when estimating contamination
#   --skip_pseudogene_correction
#                         skip identification and filtering of pseudogenes
#   --aai_strain AAI_STRAIN
#                         AAI threshold used to identify strain heterogeneity (default: 0.9)
#   -a, --alignment_file ALIGNMENT_FILE
#                         produce file showing alignment of multi-copy genes and their AAI identity
#   --ignore_thresholds   ignore model-specific score thresholds
#   -e, --e_value E_VALUE
#                         e-value cut off (default: 1e-10)
#   -l, --length LENGTH   percent overlap between target and query (default: 0.7)
#   -f, --file FILE       print results to file (default: stdout)
#   --tab_table           print tab-separated values table
#   -x, --extension EXTENSION
#                         extension of bins (other files in directory are ignored) (default: fna)
#   -t, --threads THREADS
#                         number of threads (default: 1)
#   --pplacer_threads PPLACER_THREADS
#                         number of threads used by pplacer (memory usage increases linearly with additional threads) (default: 1)
#   -q, --quiet           suppress console output
#   --tmpdir TMPDIR       specify an alternative directory for temporary files
#
# Example: checkm lineage_wf ./bins ./output
